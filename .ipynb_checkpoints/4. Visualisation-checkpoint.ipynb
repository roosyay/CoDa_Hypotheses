# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from adjustText import adjust_text
from ampligraph.discovery import find_clusters
import pandas as pd
import numpy as np

# %%
#  Retrieve triples array 

# %store -r triples_arr
X = triples_arr
print(len(X))
# Out:
# 29759

# %%
triples_df = pd.DataFrame(X, columns=['s', 'p', 'o'])

#  Sanity check 
pd.set_option('max_colwidth', 100)
triples_df
# Out:
#                                                                             s  \
# 0      https://data.cooperationdatabank.org/vocab/class/SequentialityVariable
# 1            https://data.cooperationdatabank.org/vocab/prop/sequentiality_H1
# 2                      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 3                  https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 4                  https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# ...                                                                       ...
# 29754             https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
# 29755    https://data.cooperationdatabank.org/vocab/class/PersonalityVariable
# 29756                 https://data.cooperationdatabank.org/id/ENG02672_1a.1.1
# 29757                     https://data.cooperationdatabank.org/id/ENG02672_1a
# 29758                https://data.cooperationdatabank.org/vocab/class/SVOType
#
#                                                                          p  \
# 0                          http://www.w3.org/2000/01/rdf-schema#subClassOf
# 1      https://data.cooperationdatabank.org/vocab/prop/hasPositiveEffectOn
# 2            https://data.cooperationdatabank.org/vocab/prop/sequentiality
# 3                   https://data.cooperationdatabank.org/vocab/prop/ESType
# 4        https://data.cooperationdatabank.org/vocab/prop/dependentVariable
# ...                                                                    ...
# 29754               https://data.cooperationdatabank.org/vocab/prop/ESType
# 29755                      http://www.w3.org/2000/01/rdf-schema#subClassOf
# 29756              https://data.cooperationdatabank.org/vocab/prop/sVOType
# 29757        https://data.cooperationdatabank.org/vocab/prop/reportsEffect
# 29758                      http://www.w3.org/2000/01/rdf-schema#subClassOf
#
#                                                                              o
# 0         https://data.cooperationdatabank.org/vocab/class/IndependentVariable
# 1      https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2           https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 3       https://data.cooperationdatabank.org/vocab/class/LargeMediumPositiveES
# 4      https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                        ...
# 29754             https://data.cooperationdatabank.org/vocab/class/NullFinding
# 29755     https://data.cooperationdatabank.org/vocab/class/IndependentVariable
# 29756            https://data.cooperationdatabank.org/id/svotype/individualist
# 29757              https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
# 29758     https://data.cooperationdatabank.org/vocab/class/PersonalityVariable
#
# [29759 rows x 3 columns]

# %%
#  get all the unique independent variables with the hypothesis numbers from the input triples 

variables1 = triples_df.s[triples_df.p == 'https://data.cooperationdatabank.org/vocab/prop/hasPositiveEffectOn'].unique()
variables2 = triples_df.s[triples_df.p == 'https://data.cooperationdatabank.org/vocab/prop/hasNegativeEffectOn'].unique()
variables3 = triples_df.s[triples_df.p == 'https://data.cooperationdatabank.org/vocab/prop/hasNoEffectOn'].unique()

variables = np.concatenate((variables1, variables2, variables3))
variables = np.unique(variables)

# %%
print(len(variables)) 
variables
# Out:
# 382
# array(['https://data.cooperationdatabank.org/vocab/prop/academicDiscipline_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/academicDiscipline_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/academicGradeLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/academicGradeLevel_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/academicGradeLevel_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/academicGrade_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/academicGrade_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/academicGrade_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/ageCohort_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/ageCohort_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/ageCohort_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/anchor_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/anchor_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/anchor_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/anonymityManipul_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/anonymityManipul_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/anonymityManipul_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/blockOfCooperation_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/blockOfCooperation_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/blockOfCooperation_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/cognitiveLoadTreatment_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationContent_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationContent_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationContent_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationContent_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationContent_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationOccurrence_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationOptional_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationReal_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationTreatment_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationType_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/communicationType_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexLevel_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexLevel_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H10',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H8',
#        'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue_H9',
#        'https://data.cooperationdatabank.org/vocab/prop/contextFrame_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/contextFrame_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/contextFrame_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/contextFrame_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/contextFrame_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/continuationProbability_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/costlyMonitoring_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/criticalityLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/descriptiveNorm_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/descriptiveNorm_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/descriptiveNorm_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/descriptiveNorm_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/descriptiveNorm_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/descriptiveNorm_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/emotionIntensity_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/emotionValence_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/emotionValence_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/emotionValence_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H10',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H11',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H12',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H13',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H14',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H15',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H8',
#        'https://data.cooperationdatabank.org/vocab/prop/emotion_H9',
#        'https://data.cooperationdatabank.org/vocab/prop/endogenousMotivationalOrientation_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/endogenousMotivationalOrientation_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/endowmentAssigned_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/endowmentLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/endowmentSize_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/endowmentSize_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/endowmentSize_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/endowmentSize_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/endowmentSize_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/endowmentSize_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/endowmentSize_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/entitativityLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/ethnicityUS_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/ethnicityUS_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/ethnicityUS_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/exitOption_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/expectationsLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/experimentalSetting_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/experimentalSetting_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/experimentalSetting_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/feedbackContent_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/feedbackContent_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/feedbackContent_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/feedbackTarget_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/feedbackTarget_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/feedbackTarget_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/feedbackTarget_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/feedbackTarget_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/feedbackTarget_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/focalPointFrame_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/gainLossFrame_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/gameComprehensionLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/gameIncentive_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/gameIncentive_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/gameIncentive_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/gameType_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/gameType_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/gameType_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/gameType_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/gameType_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/genderOfPartner_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/gender_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/giveTakeFrame_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/gossip_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/groupSize_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/groupSize_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/groupVariability_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/heterogeneousEthnicity_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/heterogeneousGender_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/hormoneLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/hormoneLevel_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/hormoneLevel_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/hormonesAdministration_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/hormonesAdministration_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/hormonesAdministration_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/individualMPCR_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/institutionalChoice_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/intergroupComp_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/intergroupComp_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/intergroupComp_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/intergroupComp_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/intergroupComp_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H10',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H11',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H12',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H13',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H14',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H15',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H8',
#        'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy_H9',
#        'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfExperimentalGames_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfMembership_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfMembership_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfMembership_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfPartnerPriorBehavior_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfPartnerPriorBehavior_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfPartnerPriorBehavior_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfPartnerPriorBehavior_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/knownEndGame_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/leaderBehavior_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/leaderCharacteristic_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/leaderCharacteristic_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/leaderCharacteristic_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/leadershipAssignmentRule_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/leadershipAssignmentRule_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/leadershipRole_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/leadership_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H10',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H8',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCR_H9',
#        'https://data.cooperationdatabank.org/vocab/prop/mPCRsymmetric_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/matching_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/minimumContributionValue_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/minimumContributionValue_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/minimumContributionValue_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/minimumContributionValue_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/monitoringCost_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/monitoringCost_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/monitoringCost_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/motivationalOrientation_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/motivationalOrientation_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/motivationalOrientation_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H10',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H11',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H12',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H13',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H14',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H15',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H16',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H17',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H18',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H19',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H20',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H21',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H22',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H23',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H24',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H8',
#        'https://data.cooperationdatabank.org/vocab/prop/nationality_H9',
#        'https://data.cooperationdatabank.org/vocab/prop/noise_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/oneShotStrategyValue_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/oneShotStrategyValue_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/oneShotStrategyValue_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/ostracism_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/otherGameType_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/otherGameType_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/otherGameType_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/othersBehaviorLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/ownBehaviorLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerChoice_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerEmotion_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerEmotion_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerEmotion_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerPerceptionLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerPerceptionLevel_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerPerceptionLevel_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerPerception_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerPerception_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerSelection_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerType_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerType_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerType_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerType_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/partnerType_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/partnersGenderKnownInGame_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/physicalProximity_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/positionEndogenous_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H10',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H8',
#        'https://data.cooperationdatabank.org/vocab/prop/positionInGame_H9',
#        'https://data.cooperationdatabank.org/vocab/prop/powerLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/powerLevel_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/powerLevel_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/preferenceConditionalCooperation_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/preferenceConditionalCooperation_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/preferenceConditionalCooperation_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/preferenceConditionalCooperation_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/preferenceConditionalCooperation_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/preferenceConditionalCooperation_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/primingConcept_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/primingConcept_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/primingConcept_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/primingConcept_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/primingConcept_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/primingConcept_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/privateAccountReturn_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/privateAccountReturn_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/psychopathology_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/psychopathology_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/psychopathology_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/psychopathology_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/psychopathology_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/psychopathology_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/psychopathology_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/psychopathology_H8',
#        'https://data.cooperationdatabank.org/vocab/prop/psychopathology_H9',
#        'https://data.cooperationdatabank.org/vocab/prop/publicGoodBadFrame_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentAgent_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentAgent_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentAgent_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentEffectiveness_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentEffectiveness_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentEffectiveness_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentEffectiveness_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentEffectiveness_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentIncentive_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentIncentive_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentIncentive_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentIterations_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentIterations_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentIterations_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentIterations_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentProbability_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentProbability_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentProbability_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentProbability_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentProbability_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentProbability_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentProbability_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentRule_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentSequential_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentTreatment_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentTreatment_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/punishmentTreatment_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/rebateorRefund_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/relationshipWithFocalAgent_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/relationshipWithFocalAgent_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/relationshipWithFocalAgent_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/religiousLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/restricted_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/rewardAgent_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/rewardIncentive_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/rewardProbability_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/rewardRule_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/rewardTreatment_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/rewardTreatment_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/rewardTreatment_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H10',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H8',
#        'https://data.cooperationdatabank.org/vocab/prop/sVOType_H9',
#        'https://data.cooperationdatabank.org/vocab/prop/sequentiality_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/shadowoftheFuture_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/showUpFee_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/similarityLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/society_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/stateTrustLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/stateTrustLevel_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/stateTrustLevel_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/stepReturn_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/stepReturn_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/stepReturn_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/stepReturn_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/stepReturn_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/stepReturn_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/stepReturn_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/student_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/symmetric_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/synchrony_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/targetMembership_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/targetMembership_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/targetMembership_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/targetMembership_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/targetMembership_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/threshold_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/threshold_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/threshold_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/threshold_H4',
#        'https://data.cooperationdatabank.org/vocab/prop/threshold_H5',
#        'https://data.cooperationdatabank.org/vocab/prop/threshold_H6',
#        'https://data.cooperationdatabank.org/vocab/prop/threshold_H7',
#        'https://data.cooperationdatabank.org/vocab/prop/threshold_H8',
#        'https://data.cooperationdatabank.org/vocab/prop/timePressure_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/timePressure_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/timePressure_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/trialOfCooperationOrdinal_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/trialOfCooperation_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/trialOfCooperation_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/trialOfCooperation_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/uncertaintyLevel_H1',
#        'https://data.cooperationdatabank.org/vocab/prop/uncertaintyLevel_H2',
#        'https://data.cooperationdatabank.org/vocab/prop/uncertaintyLevel_H3',
#        'https://data.cooperationdatabank.org/vocab/prop/uncertaintyTarget_H1'],
#       dtype=object)

# %%
#  Remove the hypotheses numbers

vars_series = pd.Series()

for item in variables: 
    result = item.find('_H')
    variable = item[:result]
    vars_series = vars_series.append(pd.Series([variable]))
    
unique_vars = vars_series.unique()

print(len(unique_vars))
print(unique_vars)
# Out:
# 128
# ['https://data.cooperationdatabank.org/vocab/prop/academicDiscipline'
#  'https://data.cooperationdatabank.org/vocab/prop/academicGradeLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/academicGrade'
#  'https://data.cooperationdatabank.org/vocab/prop/ageCohort'
#  'https://data.cooperationdatabank.org/vocab/prop/anchor'
#  'https://data.cooperationdatabank.org/vocab/prop/anonymityManipul'
#  'https://data.cooperationdatabank.org/vocab/prop/blockOfCooperation'
#  'https://data.cooperationdatabank.org/vocab/prop/cognitiveLoadTreatment'
#  'https://data.cooperationdatabank.org/vocab/prop/communicationContent'
#  'https://data.cooperationdatabank.org/vocab/prop/communicationOccurrence'
#  'https://data.cooperationdatabank.org/vocab/prop/communicationOptional'
#  'https://data.cooperationdatabank.org/vocab/prop/communicationReal'
#  'https://data.cooperationdatabank.org/vocab/prop/communicationTreatment'
#  'https://data.cooperationdatabank.org/vocab/prop/communicationType'
#  'https://data.cooperationdatabank.org/vocab/prop/conflictIndexLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/conflictIndexValue'
#  'https://data.cooperationdatabank.org/vocab/prop/contextFrame'
#  'https://data.cooperationdatabank.org/vocab/prop/continuationProbability'
#  'https://data.cooperationdatabank.org/vocab/prop/costlyMonitoring'
#  'https://data.cooperationdatabank.org/vocab/prop/criticalityLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/descriptiveNorm'
#  'https://data.cooperationdatabank.org/vocab/prop/emotionIntensity'
#  'https://data.cooperationdatabank.org/vocab/prop/emotionValence'
#  'https://data.cooperationdatabank.org/vocab/prop/emotion'
#  'https://data.cooperationdatabank.org/vocab/prop/endogenousMotivationalOrientation'
#  'https://data.cooperationdatabank.org/vocab/prop/endowmentAssigned'
#  'https://data.cooperationdatabank.org/vocab/prop/endowmentLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/endowmentSize'
#  'https://data.cooperationdatabank.org/vocab/prop/entitativityLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/ethnicityUS'
#  'https://data.cooperationdatabank.org/vocab/prop/exitOption'
#  'https://data.cooperationdatabank.org/vocab/prop/expectationsLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/experimentalSetting'
#  'https://data.cooperationdatabank.org/vocab/prop/feedbackContent'
#  'https://data.cooperationdatabank.org/vocab/prop/feedbackTarget'
#  'https://data.cooperationdatabank.org/vocab/prop/focalPointFrame'
#  'https://data.cooperationdatabank.org/vocab/prop/gainLossFrame'
#  'https://data.cooperationdatabank.org/vocab/prop/gameComprehensionLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/gameIncentive'
#  'https://data.cooperationdatabank.org/vocab/prop/gameType'
#  'https://data.cooperationdatabank.org/vocab/prop/genderOfPartner'
#  'https://data.cooperationdatabank.org/vocab/prop/gender'
#  'https://data.cooperationdatabank.org/vocab/prop/giveTakeFrame'
#  'https://data.cooperationdatabank.org/vocab/prop/gossip'
#  'https://data.cooperationdatabank.org/vocab/prop/groupSize'
#  'https://data.cooperationdatabank.org/vocab/prop/groupVariability'
#  'https://data.cooperationdatabank.org/vocab/prop/heterogeneousEthnicity'
#  'https://data.cooperationdatabank.org/vocab/prop/heterogeneousGender'
#  'https://data.cooperationdatabank.org/vocab/prop/hormoneLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/hormonesAdministration'
#  'https://data.cooperationdatabank.org/vocab/prop/individualMPCR'
#  'https://data.cooperationdatabank.org/vocab/prop/institutionalChoice'
#  'https://data.cooperationdatabank.org/vocab/prop/intergroupComp'
#  'https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate'
#  'https://data.cooperationdatabank.org/vocab/prop/iteratedStrategy'
#  'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfExperimentalGames'
#  'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfMembership'
#  'https://data.cooperationdatabank.org/vocab/prop/knowledgeOfPartnerPriorBehavior'
#  'https://data.cooperationdatabank.org/vocab/prop/knownEndGame'
#  'https://data.cooperationdatabank.org/vocab/prop/leaderBehavior'
#  'https://data.cooperationdatabank.org/vocab/prop/leaderCharacteristic'
#  'https://data.cooperationdatabank.org/vocab/prop/leadershipAssignmentRule'
#  'https://data.cooperationdatabank.org/vocab/prop/leadershipRole'
#  'https://data.cooperationdatabank.org/vocab/prop/leadership'
#  'https://data.cooperationdatabank.org/vocab/prop/mPCR'
#  'https://data.cooperationdatabank.org/vocab/prop/mPCRsymmetric'
#  'https://data.cooperationdatabank.org/vocab/prop/matching'
#  'https://data.cooperationdatabank.org/vocab/prop/minimumContributionValue'
#  'https://data.cooperationdatabank.org/vocab/prop/monitoringCost'
#  'https://data.cooperationdatabank.org/vocab/prop/motivationalOrientation'
#  'https://data.cooperationdatabank.org/vocab/prop/nationality'
#  'https://data.cooperationdatabank.org/vocab/prop/noise'
#  'https://data.cooperationdatabank.org/vocab/prop/oneShotStrategyValue'
#  'https://data.cooperationdatabank.org/vocab/prop/ostracism'
#  'https://data.cooperationdatabank.org/vocab/prop/otherGameType'
#  'https://data.cooperationdatabank.org/vocab/prop/othersBehaviorLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/ownBehaviorLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/partnerChoice'
#  'https://data.cooperationdatabank.org/vocab/prop/partnerEmotion'
#  'https://data.cooperationdatabank.org/vocab/prop/partnerPerceptionLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/partnerPerception'
#  'https://data.cooperationdatabank.org/vocab/prop/partnerSelection'
#  'https://data.cooperationdatabank.org/vocab/prop/partnerType'
#  'https://data.cooperationdatabank.org/vocab/prop/partnersGenderKnownInGame'
#  'https://data.cooperationdatabank.org/vocab/prop/physicalProximity'
#  'https://data.cooperationdatabank.org/vocab/prop/positionEndogenous'
#  'https://data.cooperationdatabank.org/vocab/prop/positionInGame'
#  'https://data.cooperationdatabank.org/vocab/prop/powerLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/preferenceConditionalCooperation'
#  'https://data.cooperationdatabank.org/vocab/prop/primingConcept'
#  'https://data.cooperationdatabank.org/vocab/prop/privateAccountReturn'
#  'https://data.cooperationdatabank.org/vocab/prop/psychopathology'
#  'https://data.cooperationdatabank.org/vocab/prop/publicGoodBadFrame'
#  'https://data.cooperationdatabank.org/vocab/prop/punishmentAgent'
#  'https://data.cooperationdatabank.org/vocab/prop/punishmentEffectiveness'
#  'https://data.cooperationdatabank.org/vocab/prop/punishmentIncentive'
#  'https://data.cooperationdatabank.org/vocab/prop/punishmentIterations'
#  'https://data.cooperationdatabank.org/vocab/prop/punishmentProbability'
#  'https://data.cooperationdatabank.org/vocab/prop/punishmentRule'
#  'https://data.cooperationdatabank.org/vocab/prop/punishmentSequential'
#  'https://data.cooperationdatabank.org/vocab/prop/punishmentTreatment'
#  'https://data.cooperationdatabank.org/vocab/prop/rebateorRefund'
#  'https://data.cooperationdatabank.org/vocab/prop/relationshipWithFocalAgent'
#  'https://data.cooperationdatabank.org/vocab/prop/religiousLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/restricted'
#  'https://data.cooperationdatabank.org/vocab/prop/rewardAgent'
#  'https://data.cooperationdatabank.org/vocab/prop/rewardIncentive'
#  'https://data.cooperationdatabank.org/vocab/prop/rewardProbability'
#  'https://data.cooperationdatabank.org/vocab/prop/rewardRule'
#  'https://data.cooperationdatabank.org/vocab/prop/rewardTreatment'
#  'https://data.cooperationdatabank.org/vocab/prop/sVOType'
#  'https://data.cooperationdatabank.org/vocab/prop/sequentiality'
#  'https://data.cooperationdatabank.org/vocab/prop/shadowoftheFuture'
#  'https://data.cooperationdatabank.org/vocab/prop/showUpFee'
#  'https://data.cooperationdatabank.org/vocab/prop/similarityLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/society'
#  'https://data.cooperationdatabank.org/vocab/prop/stateTrustLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/stepReturn'
#  'https://data.cooperationdatabank.org/vocab/prop/student'
#  'https://data.cooperationdatabank.org/vocab/prop/symmetric'
#  'https://data.cooperationdatabank.org/vocab/prop/synchrony'
#  'https://data.cooperationdatabank.org/vocab/prop/targetMembership'
#  'https://data.cooperationdatabank.org/vocab/prop/threshold'
#  'https://data.cooperationdatabank.org/vocab/prop/timePressure'
#  'https://data.cooperationdatabank.org/vocab/prop/trialOfCooperationOrdinal'
#  'https://data.cooperationdatabank.org/vocab/prop/trialOfCooperation'
#  'https://data.cooperationdatabank.org/vocab/prop/uncertaintyLevel'
#  'https://data.cooperationdatabank.org/vocab/prop/uncertaintyTarget']
# c:\users\roos\tf\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#  restore the trained model to retrieve the embeddings  

from ampligraph.latent_features import restore_model
model = restore_model('./best_model.pkl')

# %%
# retrieve embeddings for unique variables 

variable_embeddings = dict(zip(unique_vars, model.get_embeddings(unique_vars)))
variable_embeddings_array = np.array([i for i in variable_embeddings.values()])
variable_embeddings_array.shape
# Out:
# (128, 400)

# %%
#  function to add the prefixes for better readabilty 

def prefix_abbreviation(df):
    for name, values in df.iteritems():    
        df['variables'] = df['variables'].str.replace('https://data.cooperationdatabank.org/vocab/prop/', '')
    return df

# %%
#  UMAP demensionality reduction 

import umap.umap_ as umap
reducer = umap.UMAP()

embedding_2d = reducer.fit_transform(variable_embeddings_array)
embedding_2d.shape
# Out:
# (128, 2)

# %%
#  Sanity check
len(embedding_2d)
# Out:
# 128

# %%
# Elbow method to find right amount of clusters

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=400, random_state=0)
    kmeans.fit(embedding_2d)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#  Silhouette Analysis 

from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm

X = embedding_2d

range_n_clusters = range(10, 40) 

for n_clusters in range_n_clusters:
    
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 10 The average silhouette_score is : 0.3932625
# For n_clusters = 11 The average silhouette_score is : 0.42189205
# For n_clusters = 12 The average silhouette_score is : 0.41449553
# For n_clusters = 13 The average silhouette_score is : 0.4259212
# For n_clusters = 14 The average silhouette_score is : 0.45814788
# For n_clusters = 15 The average silhouette_score is : 0.46846154
# For n_clusters = 16 The average silhouette_score is : 0.46564323
# For n_clusters = 17 The average silhouette_score is : 0.46878242
# For n_clusters = 18 The average silhouette_score is : 0.4754454
# For n_clusters = 19 The average silhouette_score is : 0.4849391
# For n_clusters = 20 The average silhouette_score is : 0.49933386
# For n_clusters = 21 The average silhouette_score is : 0.49268413
# For n_clusters = 22 The average silhouette_score is : 0.4984397
# For n_clusters = 23 The average silhouette_score is : 0.5165183
# For n_clusters = 24 The average silhouette_score is : 0.52123225
# For n_clusters = 25 The average silhouette_score is : 0.5305753
# For n_clusters = 26 The average silhouette_score is : 0.53027976
# For n_clusters = 27 The average silhouette_score is : 0.5355419
# For n_clusters = 28 The average silhouette_score is : 0.5347679
# For n_clusters = 29 The average silhouette_score is : 0.53779984
# c:\users\roos\tf\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# For n_clusters = 30 The average silhouette_score is : 0.5372567
# For n_clusters = 31 The average silhouette_score is : 0.5404828
# For n_clusters = 32 The average silhouette_score is : 0.5396992
# For n_clusters = 33 The average silhouette_score is : 0.5412131
# For n_clusters = 34 The average silhouette_score is : 0.5422944
# For n_clusters = 35 The average silhouette_score is : 0.54071784
# For n_clusters = 36 The average silhouette_score is : 0.5287148
# For n_clusters = 37 The average silhouette_score is : 0.5447211
# For n_clusters = 38 The average silhouette_score is : 0.53479815
# For n_clusters = 39 The average silhouette_score is : 0.53261656

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=23)
kmeans.fit(embedding_2d)
y_kmeans = kmeans.predict(embedding_2d)

# %%
#  Cluster embeddings 

clustering_algorithm = KMeans(n_clusters=23, n_init=128, max_iter=500, random_state=0)
clusters = find_clusters(unique_vars, model, clustering_algorithm, mode='entity')

# %%
df = pd.DataFrame({"variables": unique_vars, 
                   "clusters": "cluster" + pd.Series(clusters).astype(str),
                   "embedding1": embedding_2d[:, 0],
                   "embedding2": embedding_2d[:, 1]})

plot_df = prefix_abbreviation(df)

# %%
pd.set_option('max_rows', 300)
plot_df
# Out:
#                                 variables   clusters  embedding1  embedding2
# 0                      academicDiscipline   cluster6    6.674539    9.924035
# 1                      academicGradeLevel   cluster6    6.849960   10.064298
# 2                           academicGrade   cluster6    7.081919   10.158986
# 3                               ageCohort  cluster10    9.515152   12.623774
# 4                                  anchor  cluster10    6.966415   11.963197
# 5                        anonymityManipul   cluster8    8.901441    9.506248
# 6                      blockOfCooperation  cluster17    7.243438   13.250728
# 7                  cognitiveLoadTreatment  cluster16    7.911054   12.768295
# 8                    communicationContent  cluster15    8.165944   13.681053
# 9                 communicationOccurrence  cluster15    8.071068   13.586336
# 10                  communicationOptional  cluster15    8.630524   13.242415
# 11                      communicationReal  cluster15    8.077782   13.061366
# 12                 communicationTreatment  cluster15    8.084784   13.587742
# 13                      communicationType  cluster15    8.256916   13.609527
# 14                     conflictIndexLevel   cluster0    7.682429   10.372671
# 15                     conflictIndexValue   cluster0    7.729361   10.467967
# 16                           contextFrame   cluster1    6.269743   12.771969
# 17                continuationProbability  cluster21    7.482894   10.898610
# 18                       costlyMonitoring   cluster0    7.403695   12.373498
# 19                       criticalityLevel  cluster18    6.472224   12.114416
# 20                        descriptiveNorm   cluster0    8.496027   12.277275
# 21                       emotionIntensity  cluster20    9.819355   10.613073
# 22                         emotionValence  cluster20   10.070363   10.921067
# 23                                emotion  cluster20   10.229589   10.868170
# 24      endogenousMotivationalOrientation   cluster9    6.371192   11.271734
# 25                      endowmentAssigned   cluster2    9.717904   12.404908
# 26                         endowmentLevel   cluster2    9.995610   11.944080
# 27                          endowmentSize   cluster2    9.998801   12.188225
# 28                      entitativityLevel  cluster21    8.077250   10.666327
# 29                            ethnicityUS  cluster22    7.432926   11.954275
# 30                             exitOption  cluster21    7.412210   10.721692
# 31                      expectationsLevel  cluster21    6.950016   12.350810
# 32                    experimentalSetting  cluster21    8.041948   10.865045
# 33                        feedbackContent   cluster7    6.968848   10.896068
# 34                         feedbackTarget   cluster7    6.958078   10.714750
# 35                        focalPointFrame   cluster1    6.602045   12.272614
# 36                          gainLossFrame   cluster1    6.411659   12.598285
# 37                 gameComprehensionLevel  cluster18    8.453931   12.130860
# 38                          gameIncentive  cluster16    7.247685   11.049151
# 39                               gameType  cluster16    7.889458    9.952780
# 40                        genderOfPartner   cluster3    7.635098    9.278465
# 41                                 gender   cluster0    7.602120   11.193822
# 42                          giveTakeFrame   cluster1    6.361130   12.657315
# 43                                 gossip   cluster8    8.833279    9.487642
# 44                              groupSize  cluster10    8.499391   12.807553
# 45                       groupVariability  cluster18    8.633337   12.472281
# 46                 heterogeneousEthnicity  cluster22    7.199849   11.603405
# 47                    heterogeneousGender   cluster0    7.596520   11.204852
# 48                           hormoneLevel  cluster18    8.882010   10.799765
# 49                 hormonesAdministration  cluster18    9.012590   10.713120
# 50                         individualMPCR   cluster2   10.123151   12.077554
# 51                    institutionalChoice  cluster10    8.550514   13.126405
# 52                         intergroupComp   cluster0    9.626153   10.854674
# 53   iteratedPreprogrammedCooperationRate  cluster13    7.140151   12.572445
# 54                       iteratedStrategy  cluster13    6.889802   12.659773
# 55           knowledgeOfExperimentalGames   cluster6    7.940871   12.222770
# 56                  knowledgeOfMembership  cluster21    8.223629   10.619707
# 57        knowledgeOfPartnerPriorBehavior   cluster8    8.783198    9.591988
# 58                           knownEndGame  cluster21    7.605647   10.779241
# 59                         leaderBehavior   cluster4    5.239620   11.436285
# 60                   leaderCharacteristic   cluster4    5.128775   11.558305
# 61               leadershipAssignmentRule   cluster4    5.189420   11.491571
# 62                         leadershipRole   cluster4    5.345234   11.326544
# 63                             leadership   cluster4    5.292779   11.419042
# 64                                   mPCR   cluster2   10.067976   12.119946
# 65                          mPCRsymmetric   cluster2    9.957888   11.935675
# 66                               matching  cluster12    8.540769   11.212343
# 67               minimumContributionValue  cluster18    8.534435   11.866717
# 68                         monitoringCost  cluster10    8.028768   12.540004
# 69                motivationalOrientation   cluster9    6.370597   11.245439
# 70                            nationality  cluster22    7.614593   12.005069
# 71                                  noise   cluster7    6.928036   10.785566
# 72                   oneShotStrategyValue  cluster13    7.097820   12.548944
# 73                              ostracism   cluster0    7.354130   11.542580
# 74                          otherGameType  cluster16    7.633759   10.046958
# 75                    othersBehaviorLevel  cluster10    8.955409   12.444054
# 76                       ownBehaviorLevel  cluster21    8.841052   12.214232
# 77                          partnerChoice  cluster12    8.645452   11.308133
# 78                         partnerEmotion  cluster20   10.139480   10.922213
# 79                 partnerPerceptionLevel   cluster3    7.587019    9.296655
# 80                      partnerPerception   cluster3    7.687856    9.235508
# 81                       partnerSelection   cluster8    8.923162    9.533831
# 82                            partnerType   cluster0    7.816769   11.452059
# 83              partnersGenderKnownInGame   cluster0    8.027059   11.617990
# 84                      physicalProximity   cluster0    8.881866   11.335474
# 85                     positionEndogenous  cluster14    8.366489   10.282326
# 86                         positionInGame  cluster14    8.269216   10.172014
# 87                             powerLevel  cluster18    7.575754   12.829679
# 88       preferenceConditionalCooperation  cluster18    8.228760   12.940944
# 89                         primingConcept  cluster16    7.790728   12.008946
# 90                   privateAccountReturn   cluster2    9.694853   12.230611
# 91                        psychopathology  cluster19    8.836576   10.545225
# 92                     publicGoodBadFrame   cluster1    6.323834   12.642832
# 93                        punishmentAgent   cluster5   10.057492   13.725080
# 94                punishmentEffectiveness   cluster5   10.011129   13.645536
# 95                    punishmentIncentive   cluster5    9.864657   13.560061
# 96                   punishmentIterations   cluster5   10.062775   13.735426
# 97                  punishmentProbability   cluster5   10.028251   13.755017
# 98                         punishmentRule  cluster10    9.117899   12.880152
# 99                   punishmentSequential   cluster5    9.742683   13.445146
# 100                   punishmentTreatment   cluster5    9.947623   13.768444
# 101                        rebateorRefund   cluster0    7.145573   11.359041
# 102            relationshipWithFocalAgent  cluster21    7.093708   11.800774
# 103                        religiousLevel  cluster18    8.963344   11.696033
# 104                            restricted  cluster15    7.898937   13.457915
# 105                           rewardAgent  cluster11    9.110846   11.303166
# 106                       rewardIncentive  cluster11    9.234527   11.631976
# 107                     rewardProbability  cluster11    8.468793   11.397840
# 108                            rewardRule  cluster11    9.333936   11.414561
# 109                       rewardTreatment  cluster11    9.420798   11.522059
# 110                               sVOType  cluster19    9.001495   10.671099
# 111                         sequentiality  cluster14    8.435999   10.391645
# 112                     shadowoftheFuture   cluster0    6.663805   12.059168
# 113                             showUpFee  cluster16    6.750262   11.193032
# 114                       similarityLevel   cluster3    7.617433    9.300886
# 115                               society  cluster22    7.547338   12.305437
# 116                       stateTrustLevel  cluster10    9.151754   12.865138
# 117                            stepReturn   cluster0    7.663558   11.719494
# 118                               student   cluster6    6.718047    9.948977
# 119                             symmetric  cluster21    8.146976   11.206240
# 120                             synchrony  cluster16    6.643236   11.509812
# 121                      targetMembership  cluster21    8.232609   10.729011
# 122                             threshold   cluster0    7.961722   11.938580
# 123                          timePressure  cluster10    9.336482   13.236388
# 124             trialOfCooperationOrdinal  cluster17    7.215945   13.173565
# 125                    trialOfCooperation  cluster17    7.041666   12.921658
# 126                      uncertaintyLevel  cluster18    8.939301   12.474586
# 127                     uncertaintyTarget  cluster18    8.257983   12.503280

# %%
#  Create figure 

X = embedding_2d
centers = kmeans.cluster_centers_

plt.figure(figsize=(30, 30))
texts = []

for i, point in plot_df.iterrows():
    texts.append(plt.text(point['embedding1']+0.02,
                 point['embedding2']+0.01,
                 str(point["variables"]), fontsize = 20))
ax = plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=80, cmap='gist_rainbow')
plt.scatter(centers[:, 0], centers[:, 1], c='grey', s=500, alpha=0.5, marker='o');

for i, c in enumerate(centers):
    r = i+1
    plt.scatter(c[0], c[1], marker='$%d$' % r, c='black', alpha=1, s=200, edgecolor='k')

plt.xlabel('embedding dimension 1', fontsize=20)
plt.ylabel('embedding dimension 2', fontsize=20)
adjust_text(texts)
# Out:
# 500
