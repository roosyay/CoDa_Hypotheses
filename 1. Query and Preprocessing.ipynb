# %%
import json
# import SPARQLWrapper
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import numpy as np
from tqdm import tqdm
# import rdflib
import math
import ast

# %%
# functions for SPARQL queries to pandas dataframes 

url = 'https://api.cooperationdatabank.org/datasets/coda/databank/services/databank/sparql'

#  SPARQL queries for more then 10,000 triples
#  set num_iter to amount of expected returned triples (e.g. 20 for 20,000 triples) 
def get_sparql_dataframe(service, query):
    sparql = SPARQLWrapper(service)
    out = []
    num_iter = 20
    
    for i in range(num_iter):
        sparql.setQuery(query + " OFFSET " + str(i) + "000")
        sparql.setReturnFormat(JSON)
        result = sparql.query()
        processed_results = json.load(result.response)
        cols = processed_results['head']['vars']

        for row in processed_results['results']['bindings']:
            item = []
            for c in cols:
                item.append(row.get(c, {}).get('value'))
            out.append(item)
        
    return pd.DataFrame(out, columns=cols)


#  SPARQL queries for less then 10,000 triples 
def get_sparql_dataframe_small(service, query):
    sparql = SPARQLWrapper(service)
    out = []
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()
    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)
        
    return pd.DataFrame(out, columns=cols)

#  SPARQL construct queries for less then 10,000 triples 
def get_sparql_dataframe_construct(service, query):
    sparql = SPARQLWrapper(service)
    out = []
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()
    processed_results = json.load(result.response)
    cols = ['s', 'p', 'o']

    for row in processed_results:
        item = []
        for c in cols:
            item.append(row.get(c))
        out.append(item)
        
    return pd.DataFrame(out, columns=cols)

# %% [markdown]
# # 1. Data Selection

# %%
#  Get all useful observations for preprocessing

query = """
PREFIX property: <https://data.cooperationdatabank.org/vocab/prop/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX id: <https://data.cooperationdatabank.org/id/>
PREFIX class: <https://data.cooperationdatabank.org/vocab/class/>

SELECT * WHERE {
  
  # ?obs rdf:type class:Observation .
  # ?obs property:eSmeasure <https://data.cooperationdatabank.org/id/esmeasure/d> . 
  # ?obs property:dependentVariable ?dependent . 
  # ?obs property:eSEstimate ?ES .
  # ?obs property:effectSizeSampleSize ?N . 

  # ?obs property:treatment ?t1, ?t2 . 
  # ?study property:reportsEffect ?obs . 
  # ?t1 property:betweenOrWithinParticipantsDesign ?design . 


OPTIONAL {
  # ?t1 property:nCondition ?n1 . 
  # ?t2 property:nCondition ?n2 .

  # ?t1 property:sDforCondition ?sd1 . 
  # ?t2 property:sDforCondition ?sd2 .
  } 

OPTIONAL { 
  # ?obs property:effectSizeLowerLimit ?ESLower . 
  # ?obs property:effectSizeUpperLimit ?ESUpper .  
}

OPTIONAL {
  # ?paper property:study ?study . 
  # ?paper property:doi ?doi . }
  
  FILTER (?t1 < ?t2) 
} 
"""

observations = get_sparql_dataframe_small(url, query)

# %%
#  inspect dataframe 

pd.set_option('max_colwidth', 100)
pd.set_option('max_row', 100)
observations
# Out:
#                                                              obs  \
# 0     https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 1     https://data.cooperationdatabank.org/id/ENG00008_1.4.1.3.d
# 2     https://data.cooperationdatabank.org/id/ENG00008_1.4.2.3.d
# 3     https://data.cooperationdatabank.org/id/ENG00008_2.1.1.2.d
# 4     https://data.cooperationdatabank.org/id/ENG00008_2.2.1.2.d
# ...                                                          ...
# 4767  https://data.cooperationdatabank.org/id/ENG02674_1.1.1.2.d
# 4768  https://data.cooperationdatabank.org/id/ENG02682_1.2.1.2.d
# 4769  https://data.cooperationdatabank.org/id/ENG02690_1.2.1.2.d
# 4770  https://data.cooperationdatabank.org/id/ENG02506_1.5.1.2.d
# 4771  https://data.cooperationdatabank.org/id/JPN00102_1.1.1.2.d
#
#                                                                     dependent  \
# 0     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 1     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 3     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 4     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                       ...
# 4767  https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 4768    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 4769  https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 4770    https://data.cooperationdatabank.org/id/dependentvariable/withdrawals
# 4771    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
#
#               ES      N  \
# 0        1.24393   57.0
# 1        1.08443   57.0
# 2     -0.0872995   58.0
# 3      -0.324082  192.0
# 4       0.315689  144.0
# ...          ...    ...
# 4767    -0.11775   80.0
# 4768    0.158607   40.0
# 4769   -0.141421   50.0
# 4770    -1.29771   11.0
# 4771    0.262907  120.0
#
#                                                           t1  \
# 0     https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 1     https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 2     https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 3     https://data.cooperationdatabank.org/id/ENG00008_2.1.1
# 4     https://data.cooperationdatabank.org/id/ENG00008_2.2.1
# ...                                                      ...
# 4767  https://data.cooperationdatabank.org/id/ENG02674_1.1.1
# 4768  https://data.cooperationdatabank.org/id/ENG02682_1.2.1
# 4769  https://data.cooperationdatabank.org/id/ENG02690_1.2.1
# 4770  https://data.cooperationdatabank.org/id/ENG02506_1.5.1
# 4771  https://data.cooperationdatabank.org/id/JPN00102_1.1.1
#
#                                                           t2  \
# 0     https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 1     https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 2     https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 3     https://data.cooperationdatabank.org/id/ENG00008_2.1.2
# 4     https://data.cooperationdatabank.org/id/ENG00008_2.2.2
# ...                                                      ...
# 4767  https://data.cooperationdatabank.org/id/ENG02674_1.1.2
# 4768  https://data.cooperationdatabank.org/id/ENG02682_1.2.2
# 4769  https://data.cooperationdatabank.org/id/ENG02690_1.2.2
# 4770  https://data.cooperationdatabank.org/id/ENG02506_1.5.2
# 4771  https://data.cooperationdatabank.org/id/JPN00102_1.1.2
#
#                                                    study  \
# 0     https://data.cooperationdatabank.org/id/ENG00008_1
# 1     https://data.cooperationdatabank.org/id/ENG00008_1
# 2     https://data.cooperationdatabank.org/id/ENG00008_1
# 3     https://data.cooperationdatabank.org/id/ENG00008_2
# 4     https://data.cooperationdatabank.org/id/ENG00008_2
# ...                                                  ...
# 4767  https://data.cooperationdatabank.org/id/ENG02674_1
# 4768  https://data.cooperationdatabank.org/id/ENG02682_1
# 4769  https://data.cooperationdatabank.org/id/ENG02690_1
# 4770  https://data.cooperationdatabank.org/id/ENG02506_1
# 4771  https://data.cooperationdatabank.org/id/JPN00102_1
#
#                                                                            design  \
# 0     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 1     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# ...                                                                           ...
# 4767  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4768  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4769  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4770  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4771  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
#
#         n1    n2    sd1    sd2     ESLower     ESUpper  \
# 0       28    29   3.36    3.7    0.676655      1.8112
# 1       28    29   3.36   4.08    0.528299     1.64057
# 2       29    29    3.7   4.08   -0.602256    0.427657
# 3       96    96  3.288  4.281    -0.60883  -0.0393351
# 4       96    48   3.91   3.52  -0.0326996    0.664078
# ...    ...   ...    ...    ...         ...         ...
# 4767  None  None   None   None   -0.617696    0.382197
# 4768  None  None   None   None   -0.589394    0.906608
# 4769  None  None   None   None   -0.696475    0.413633
# 4770  None  None   None   None    -2.59807  0.00265933
# 4771  None  None   None   None  -0.0964745    0.622288
#
#                                                  paper  \
# 0     https://data.cooperationdatabank.org/id/ENG00008
# 1     https://data.cooperationdatabank.org/id/ENG00008
# 2     https://data.cooperationdatabank.org/id/ENG00008
# 3     https://data.cooperationdatabank.org/id/ENG00008
# 4     https://data.cooperationdatabank.org/id/ENG00008
# ...                                                ...
# 4767  https://data.cooperationdatabank.org/id/ENG02674
# 4768  https://data.cooperationdatabank.org/id/ENG02682
# 4769  https://data.cooperationdatabank.org/id/ENG02690
# 4770  https://data.cooperationdatabank.org/id/ENG02506
# 4771                                              None
#
#                                                      doi
# 0           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 1           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 2           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 3           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 4           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# ...                                                  ...
# 4767  http://dx.doi.org/10.1111/j.1813-6982.2007.00127.x
# 4768    http://dx.doi.org/10.1016/j.jtrangeo.2013.05.012
# 4769          http://dx.doi.org/10.1177/0146167210391103
# 4770    http://dx.doi.org/10.1016/j.ecolecon.2008.01.015
# 4771                                                None
#
# [4772 rows x 16 columns]

# %%
#  set dtypes

observations['independentProperties'] = np.nan
observations = observations.astype('object')
observations.dtypes
# Out:
# obs                      object
# dependent                object
# ES                       object
# N                        object
# t1                       object
# t2                       object
# study                    object
# design                   object
# n1                       object
# n2                       object
# sd1                      object
# sd2                      object
# ESLower                  object
# ESUpper                  object
# paper                    object
# doi                      object
# independentProperties    object
# dtype: object

# %%
def find_differences(t1,t2): 
    t1 = t1.reset_index(drop=True)
    t2 = t2.reset_index(drop=True)
    
    df = pd.concat([t1, t2], keys=['t1', 't2'])
    df_gpby = df.groupby(list(df.columns))
    idx = [x[0] for x in df_gpby.groups.values() if len(x) == 1]
    
    return df.reindex(idx).sort_index()


#  Filter out non-relevant predicates
def filter_predicates(some_list):
    
    #  These predicates usually differ for all treatments that have them 
    filter_outs = ['http://www.w3.org/2000/01/rdf-schema#label',
                   'https://data.cooperationdatabank.org/vocab/prop/meanContributionOrWithdrawalForCondition',
                   'https://data.cooperationdatabank.org/vocab/prop/nCondition',
                   'https://data.cooperationdatabank.org/vocab/prop/sDforCondition', 
                   'https://data.cooperationdatabank.org/vocab/prop/proportionOfCooperationCondition', 
                   'https://data.cooperationdatabank.org/vocab/prop/individualDifferenceLevel',
                   'https://data.cooperationdatabank.org/vocab/prop/nbOfLevels'] 
    
    for uri in filter_outs: 
        if uri in some_list: 
            some_list.remove(uri)
    
    return some_list 

#  Find all the predicates on which two treatments differ 
def find_differing_independents(obs): 
    outcome = pd.DataFrame()
    loop = tqdm(total = len(obs), position=0, leave=False)
    
    for i, row in obs.iterrows(): 
        row = observations.loc[i]
        observation = row['obs']
        treatments = {'t1': outcome, 't2': outcome}

        for treatment in treatments: 
            query = """
                        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
                        PREFIX class: <https://data.cooperationdatabank.org/vocab/class/>

                        SELECT ?p ?o WHERE {
                         <""" + str(row[treatment]) + """> ?p ?o .                   
                        } 
                        """

            treatments[treatment] = get_sparql_dataframe_small(url, query)
        
        #  Show percentage bar
        loop.set_description("Loading...".format(i))
        loop.update(1)

        df_differences = find_differences(treatments['t1'].sort_values(by=['p']) , treatments['t2'].sort_values(by=['p']))
        df_differences = df_differences.reset_index(drop=True)
        only_in_one_t = df_differences['p'].drop_duplicates(keep=False).index
        different_predicates = df_differences['p'].drop(only_in_one_t).unique().tolist()
        independent_variables = filter_predicates(different_predicates)
        
        if independent_variables == []: 
            obs = obs.drop([i])
        else: 
            obs.at[i, 'independentProperties'] = independent_variables

    loop.close()
    return obs 
observations = find_differing_independents(observations)

# %%
#  inspect observations table again 
observations = observations.reset_index(drop=True)
pd.set_option('max_rows', 100)
pd.set_option('max_colwidth', 100)
observations
# Out:
#                                                               obs  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.3.d
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2.3.d
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1.2.d
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1.2.d
# ...                                                           ...
# 3246   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.3.d
# 3247   https://data.cooperationdatabank.org/id/ENG02668_1.2.2.3.d
# 3248  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
# 3249   https://data.cooperationdatabank.org/id/ENG02674_1.1.1.2.d
# 3250   https://data.cooperationdatabank.org/id/ENG02682_1.2.1.2.d
#
#                                                                     dependent  \
# 0     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 1     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 3     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 4     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                       ...
# 3246    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 3247    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 3248    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 3249  https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 3250    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
#
#               ES      N  \
# 0        1.24393   57.0
# 1        1.08443   57.0
# 2     -0.0872995   58.0
# 3      -0.324082  192.0
# 4       0.315689  144.0
# ...          ...    ...
# 3246    0.719742  126.0
# 3247  -0.0193469  107.0
# 3248  -0.0690061   37.0
# 3249    -0.11775   80.0
# 3250    0.158607   40.0
#
#                                                            t1  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1
# ...                                                       ...
# 3246   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 3247   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 3248  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1
# 3249   https://data.cooperationdatabank.org/id/ENG02674_1.1.1
# 3250   https://data.cooperationdatabank.org/id/ENG02682_1.2.1
#
#                                                            t2  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.2
# ...                                                       ...
# 3246   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 3247   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 3248  https://data.cooperationdatabank.org/id/ENG02672_1a.1.2
# 3249   https://data.cooperationdatabank.org/id/ENG02674_1.1.2
# 3250   https://data.cooperationdatabank.org/id/ENG02682_1.2.2
#
#                                                     study  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1
# 3      https://data.cooperationdatabank.org/id/ENG00008_2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2
# ...                                                   ...
# 3246   https://data.cooperationdatabank.org/id/ENG02668_1
# 3247   https://data.cooperationdatabank.org/id/ENG02668_1
# 3248  https://data.cooperationdatabank.org/id/ENG02672_1a
# 3249   https://data.cooperationdatabank.org/id/ENG02674_1
# 3250   https://data.cooperationdatabank.org/id/ENG02682_1
#
#                                                                            design  \
# 0     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 1     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# ...                                                                           ...
# 3246  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3247  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3248  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3249  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3250  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
#
#         n1    n2    sd1    sd2     ESLower     ESUpper  \
# 0       28    29   3.36    3.7    0.676655      1.8112
# 1       28    29   3.36   4.08    0.528299     1.64057
# 2       29    29    3.7   4.08   -0.602256    0.427657
# 3       96    96  3.288  4.281    -0.60883  -0.0393351
# 4       96    48   3.91   3.52  -0.0326996    0.664078
# ...    ...   ...    ...    ...         ...         ...
# 3246  None  None   None   None    0.297905     1.14158
# 3247  None  None   None   None    -0.43813    0.399437
# 3248  None  None   None   None   -0.888749    0.750737
# 3249  None  None   None   None   -0.617696    0.382197
# 3250  None  None   None   None   -0.589394    0.906608
#
#                                                  paper  \
# 0     https://data.cooperationdatabank.org/id/ENG00008
# 1     https://data.cooperationdatabank.org/id/ENG00008
# 2     https://data.cooperationdatabank.org/id/ENG00008
# 3     https://data.cooperationdatabank.org/id/ENG00008
# 4     https://data.cooperationdatabank.org/id/ENG00008
# ...                                                ...
# 3246  https://data.cooperationdatabank.org/id/ENG02668
# 3247  https://data.cooperationdatabank.org/id/ENG02668
# 3248  https://data.cooperationdatabank.org/id/ENG02672
# 3249  https://data.cooperationdatabank.org/id/ENG02674
# 3250  https://data.cooperationdatabank.org/id/ENG02682
#
#                                                      doi  \
# 0           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 1           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 2           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 3           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 4           http://dx.doi.org/10.1016/j.jesp.2004.09.004
# ...                                                  ...
# 3246                                http://dx.doi.org/NA
# 3247                                http://dx.doi.org/NA
# 3248                                http://dx.doi.org/NA
# 3249  http://dx.doi.org/10.1111/j.1813-6982.2007.00127.x
# 3250    http://dx.doi.org/10.1016/j.jtrangeo.2013.05.012
#
#                                                                                     independentProperties
# 0                                         [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 1                                         [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 2                                        [https://data.cooperationdatabank.org/vocab/prop/positionInGame]
# 3                                     [https://data.cooperationdatabank.org/vocab/prop/expectationsLevel]
# 4                                         [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# ...                                                                                                   ...
# 3246                                            [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 3247                                            [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 3248                                            [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 3249  [https://data.cooperationdatabank.org/vocab/prop/endowmentSize, https://data.cooperationdatabank...
# 3250  [https://data.cooperationdatabank.org/vocab/prop/groupSize, https://data.cooperationdatabank.org...
#
# [3251 rows x 17 columns]

# %%
#  get all observations that only differ on one property 
listje = []

def unique(trends): 
    output = []
    for x in trends:
        if x not in output:
            output.append(x)
    return output
 
for index, row in observations.iterrows(): 
    if len(row['independentProperties']) == 1: 
        listje.append(row['obs'])
        
unique_obs = unique(listje)
len(unique_obs)
# Out:
# 2491

# %%
#  get the data table with the observations that differ on only one property
observations_unique = observations[observations['obs'].isin(unique_obs)]

# %%
# Store if you don't continue right away, to not have to run slow code again 
# %store observations_unique
# Out:
# Stored 'observations_with_unique_independents' (DataFrame)

# %%
# %store -r observations_unique
observations_unique
# Out:
#                                                               obs  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.3.d
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2.3.d
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1.2.d
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1.2.d
# ...                                                           ...
# 3244  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2.3.d
# 3245   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.2.d
# 3246   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.3.d
# 3247   https://data.cooperationdatabank.org/id/ENG02668_1.2.2.3.d
# 3248  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
#
#                                                                     dependent  \
# 0     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 1     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 3     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 4     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                       ...
# 3244    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 3245    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 3246    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 3247    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 3248    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
#
#               ES      N  \
# 0        1.24393   57.0
# 1        1.08443   57.0
# 2     -0.0872995   58.0
# 3      -0.324082  192.0
# 4       0.315689  144.0
# ...          ...    ...
# 3244    0.100519   48.0
# 3245    0.739089  127.0
# 3246    0.719742  126.0
# 3247  -0.0193469  107.0
# 3248  -0.0690061   37.0
#
#                                                            t1  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1
# ...                                                       ...
# 3244  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2
# 3245   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 3246   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 3247   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 3248  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1
#
#                                                            t2  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.2
# ...                                                       ...
# 3244  https://data.cooperationdatabank.org/id/ENG02667_1b.2.3
# 3245   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 3246   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 3247   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 3248  https://data.cooperationdatabank.org/id/ENG02672_1a.1.2
#
#                                                     study  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1
# 3      https://data.cooperationdatabank.org/id/ENG00008_2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2
# ...                                                   ...
# 3244  https://data.cooperationdatabank.org/id/ENG02667_1b
# 3245   https://data.cooperationdatabank.org/id/ENG02668_1
# 3246   https://data.cooperationdatabank.org/id/ENG02668_1
# 3247   https://data.cooperationdatabank.org/id/ENG02668_1
# 3248  https://data.cooperationdatabank.org/id/ENG02672_1a
#
#                                                                            design  \
# 0     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 1     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# ...                                                                           ...
# 3244  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3245  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3246  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3247  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3248  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
#
#         n1    n2    sd1    sd2     ESLower     ESUpper  \
# 0       28    29   3.36    3.7    0.676655      1.8112
# 1       28    29   3.36   4.08    0.528299     1.64057
# 2       29    29    3.7   4.08   -0.602256    0.427657
# 3       96    96  3.288  4.281    -0.60883  -0.0393351
# 4       96    48   3.91   3.52  -0.0326996    0.664078
# ...    ...   ...    ...    ...         ...         ...
# 3244  None  None   None   None   -0.552567    0.753605
# 3245  None  None   None   None     0.31896     1.15922
# 3246  None  None   None   None    0.297905     1.14158
# 3247  None  None   None   None    -0.43813    0.399437
# 3248  None  None   None   None   -0.888749    0.750737
#
#                                                  paper  \
# 0     https://data.cooperationdatabank.org/id/ENG00008
# 1     https://data.cooperationdatabank.org/id/ENG00008
# 2     https://data.cooperationdatabank.org/id/ENG00008
# 3     https://data.cooperationdatabank.org/id/ENG00008
# 4     https://data.cooperationdatabank.org/id/ENG00008
# ...                                                ...
# 3244  https://data.cooperationdatabank.org/id/ENG02667
# 3245  https://data.cooperationdatabank.org/id/ENG02668
# 3246  https://data.cooperationdatabank.org/id/ENG02668
# 3247  https://data.cooperationdatabank.org/id/ENG02668
# 3248  https://data.cooperationdatabank.org/id/ENG02672
#
#                                                doi  \
# 0     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 1     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 2     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 3     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 4     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# ...                                            ...
# 3244   http://dx.doi.org/10.2466/pr0.1975.36.2.371
# 3245                          http://dx.doi.org/NA
# 3246                          http://dx.doi.org/NA
# 3247                          http://dx.doi.org/NA
# 3248                          http://dx.doi.org/NA
#
#                                                                        independentProperties
# 0                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 1                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 2                           [https://data.cooperationdatabank.org/vocab/prop/positionInGame]
# 3                        [https://data.cooperationdatabank.org/vocab/prop/expectationsLevel]
# 4                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# ...                                                                                      ...
# 3244  [https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate]
# 3245                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 3246                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 3247                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 3248                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
#
# [2491 rows x 17 columns]

# %%
observations_unique[["ES", "N", "n1", "n2", "sd1", "sd2", "ESLower", "ESUpper"]] = observations_unique[["ES", 
                           "N", "n1", "n2", "sd1", "sd2", "ESLower", "ESUpper"]].astype('float')

# %%
observations_unique.dtypes
# Out:
# obs                       object
# dependent                 object
# ES                       float64
# N                        float64
# t1                        object
# t2                        object
# study                     object
# design                    object
# n1                       float64
# n2                       float64
# sd1                      float64
# sd2                      float64
# ESLower                  float64
# ESUpper                  float64
# paper                     object
# doi                       object
# independentProperties     object
# dtype: object

# %%
observations_unique['ESLower'].isnull().sum()
# Out:
# 13

# %% [markdown]
# # Code for Calculating the standard error
# (not used for the current approach)

# %%
# Calculate SE for observations that contain extra metrics 
def calculate_SE(obs):
    for index, row in obs.iterrows(): 
        N = float(row['N'])
        ES = float(row['ES'])
        
      # Values from CoDa treatment 1 
        n1 = float(row['n1'])
        s1 = float(row['sd1'])

        # Values from CoDa treatment 2 
        n2 = float(row['n2'])
        s2 = float(row['sd2']) 
        
        if math.isnan(n1) or math.isnan(s1) or math.isnan(n2) or math.isnan(s2): 
            continue 
        else:    

            #  Between participants design 
            if row['design'] == 'https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1':         

                # Hedges' pooled and weighted standard deviation 
                SD_pooled = math.sqrt((((n1-1)*(s1**2)) + ((n2-1)*(s2**2)))/(n1+n2-2))

                #  standard error for treatment 1 and 2 respectively 
                SE1 = s1 / math.sqrt(n1)
                SE2 = s2 / math.sqrt(n2)

                #  standard error for difference of the means 
                SE_group_mean_difference = math.sqrt((SE1**2)+(SE2**2))

                #  standard error for the effect size 
                SE_effect_size = SE_group_mean_difference/SD_pooled


            #  Within participants design 
            elif row['design'] == 'https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/2':

                #  NOT SURE ABOUT THIS, approximation of the sd of differences 
                SD_difference = math.sqrt((((n1-1)*(s1**2)) + ((n2-1)*(s2**2))) / (n1 + n2 - 2)) 
                SE_difference = SD_difference / math.sqrt(N)

                # Standard deviation of the first treatment is used, don't have argumentation for this yet 
                SE_effect_size = SE_difference / s1


            obs.at[index, 'SE'] = SE_effect_size

    return obs

# %%
obs = calculate_SE(observations_with_unique_independents)

# %% [markdown]
# # 2. Create ComplEx Input
# ## 2.1 Find IV Values

# %%
obs = observations_with_unique_independents.reset_index(drop=True)
obs['categoryT1'] = np.nan
obs['categoryT2'] = np.nan

# %%
obs[["categoryT1", "categoryT2"]] = obs[["categoryT1", "categoryT2"]].astype('object')

# %%
obs
# Out:
#                                                               obs  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.3.d
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2.3.d
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1.2.d
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1.2.d
# ...                                                           ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2.3.d
# 2487   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.2.d
# 2488   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.3.d
# 2489   https://data.cooperationdatabank.org/id/ENG02668_1.2.2.3.d
# 2490  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
#
#                                                                     dependent  \
# 0     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 1     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 3     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 4     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                       ...
# 2486    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2487    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2488    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2489    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2490    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
#
#             ES      N  \
# 0     1.243930   57.0
# 1     1.084430   57.0
# 2    -0.087300   58.0
# 3    -0.324082  192.0
# 4     0.315689  144.0
# ...        ...    ...
# 2486  0.100519   48.0
# 2487  0.739089  127.0
# 2488  0.719742  126.0
# 2489 -0.019347  107.0
# 2490 -0.069006   37.0
#
#                                                            t1  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1
# ...                                                       ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2
# 2487   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 2488   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 2489   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 2490  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1
#
#                                                            t2  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.2
# ...                                                       ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667_1b.2.3
# 2487   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 2488   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 2489   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 2490  https://data.cooperationdatabank.org/id/ENG02672_1a.1.2
#
#                                                     study  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1
# 3      https://data.cooperationdatabank.org/id/ENG00008_2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2
# ...                                                   ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667_1b
# 2487   https://data.cooperationdatabank.org/id/ENG02668_1
# 2488   https://data.cooperationdatabank.org/id/ENG02668_1
# 2489   https://data.cooperationdatabank.org/id/ENG02668_1
# 2490  https://data.cooperationdatabank.org/id/ENG02672_1a
#
#                                                                            design  \
# 0     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 1     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# ...                                                                           ...
# 2486  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2487  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2488  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2489  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2490  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
#
#         n1    n2    sd1    sd2   ESLower   ESUpper  \
# 0     28.0  29.0  3.360  3.700  0.676655  1.811200
# 1     28.0  29.0  3.360  4.080  0.528299  1.640570
# 2     29.0  29.0  3.700  4.080 -0.602256  0.427657
# 3     96.0  96.0  3.288  4.281 -0.608830 -0.039335
# 4     96.0  48.0  3.910  3.520 -0.032700  0.664078
# ...    ...   ...    ...    ...       ...       ...
# 2486   NaN   NaN    NaN    NaN -0.552567  0.753605
# 2487   NaN   NaN    NaN    NaN  0.318960  1.159220
# 2488   NaN   NaN    NaN    NaN  0.297905  1.141580
# 2489   NaN   NaN    NaN    NaN -0.438130  0.399437
# 2490   NaN   NaN    NaN    NaN -0.888749  0.750737
#
#                                                  paper  \
# 0     https://data.cooperationdatabank.org/id/ENG00008
# 1     https://data.cooperationdatabank.org/id/ENG00008
# 2     https://data.cooperationdatabank.org/id/ENG00008
# 3     https://data.cooperationdatabank.org/id/ENG00008
# 4     https://data.cooperationdatabank.org/id/ENG00008
# ...                                                ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667
# 2487  https://data.cooperationdatabank.org/id/ENG02668
# 2488  https://data.cooperationdatabank.org/id/ENG02668
# 2489  https://data.cooperationdatabank.org/id/ENG02668
# 2490  https://data.cooperationdatabank.org/id/ENG02672
#
#                                                doi  \
# 0     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 1     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 2     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 3     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 4     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# ...                                            ...
# 2486   http://dx.doi.org/10.2466/pr0.1975.36.2.371
# 2487                          http://dx.doi.org/NA
# 2488                          http://dx.doi.org/NA
# 2489                          http://dx.doi.org/NA
# 2490                          http://dx.doi.org/NA
#
#                                                                        independentProperties  \
# 0                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 1                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 2                           [https://data.cooperationdatabank.org/vocab/prop/positionInGame]
# 3                        [https://data.cooperationdatabank.org/vocab/prop/expectationsLevel]
# 4                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# ...                                                                                      ...
# 2486  [https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate]
# 2487                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 2488                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 2489                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 2490                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
#
#      categoryT1 categoryT2
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 2486        NaN        NaN
# 2487        NaN        NaN
# 2488        NaN        NaN
# 2489        NaN        NaN
# 2490        NaN        NaN
#
# [2491 rows x 19 columns]

# %%
def get_category_query(treatment, independent):
    query = """
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            PREFIX class: <https://data.cooperationdatabank.org/vocab/class/>

            SELECT ?o WHERE {
             <""" + treatment + """> <""" + independent + """> ?o .                   
            } 
            """
    
    cat_df = get_sparql_dataframe_small(url, query)
    cat = cat_df['o'][0]
    return cat

#  Get the IV values 
def get_categories(obs): 
    loop = tqdm(total = len(obs), position=0, leave=False)
    
    for i, row in obs.iterrows(): 
        
        observation = row['obs']
        t1 = row['t1']
        t2 = row['t2']
#         independent = ast.literal_eval(row['independentProperties'])[0]
        independent = row['independentProperties'][0]
        try: 
            catT1 = get_category_query(t1, independent)
            catT2 = get_category_query(t2, independent)

            obs.at[i, 'categoryT1'] = catT1
            obs.at[i, 'categoryT2'] = catT2
            
        except: 
            continue
        #  Show percentage bar
        loop.set_description("Loading...".format(i))
        loop.update(1)

    loop.close()
    return obs 
obs = get_categories(obs)

# %%
obs
# Out:
#                                                               obs  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.3.d
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2.3.d
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1.2.d
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1.2.d
# ...                                                           ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2.3.d
# 2487   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.2.d
# 2488   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.3.d
# 2489   https://data.cooperationdatabank.org/id/ENG02668_1.2.2.3.d
# 2490  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
#
#                                                                     dependent  \
# 0     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 1     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 3     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 4     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                       ...
# 2486    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2487    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2488    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2489    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2490    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
#
#             ES      N  \
# 0     1.243930   57.0
# 1     1.084430   57.0
# 2    -0.087300   58.0
# 3    -0.324082  192.0
# 4     0.315689  144.0
# ...        ...    ...
# 2486  0.100519   48.0
# 2487  0.739089  127.0
# 2488  0.719742  126.0
# 2489 -0.019347  107.0
# 2490 -0.069006   37.0
#
#                                                            t1  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1
# ...                                                       ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2
# 2487   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 2488   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 2489   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 2490  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1
#
#                                                            t2  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.2
# ...                                                       ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667_1b.2.3
# 2487   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 2488   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 2489   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 2490  https://data.cooperationdatabank.org/id/ENG02672_1a.1.2
#
#                                                     study  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1
# 3      https://data.cooperationdatabank.org/id/ENG00008_2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2
# ...                                                   ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667_1b
# 2487   https://data.cooperationdatabank.org/id/ENG02668_1
# 2488   https://data.cooperationdatabank.org/id/ENG02668_1
# 2489   https://data.cooperationdatabank.org/id/ENG02668_1
# 2490  https://data.cooperationdatabank.org/id/ENG02672_1a
#
#                                                                            design  \
# 0     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 1     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# ...                                                                           ...
# 2486  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2487  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2488  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2489  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2490  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
#
#         n1    n2    sd1    sd2   ESLower   ESUpper  \
# 0     28.0  29.0  3.360  3.700  0.676655  1.811200
# 1     28.0  29.0  3.360  4.080  0.528299  1.640570
# 2     29.0  29.0  3.700  4.080 -0.602256  0.427657
# 3     96.0  96.0  3.288  4.281 -0.608830 -0.039335
# 4     96.0  48.0  3.910  3.520 -0.032700  0.664078
# ...    ...   ...    ...    ...       ...       ...
# 2486   NaN   NaN    NaN    NaN -0.552567  0.753605
# 2487   NaN   NaN    NaN    NaN  0.318960  1.159220
# 2488   NaN   NaN    NaN    NaN  0.297905  1.141580
# 2489   NaN   NaN    NaN    NaN -0.438130  0.399437
# 2490   NaN   NaN    NaN    NaN -0.888749  0.750737
#
#                                                  paper  \
# 0     https://data.cooperationdatabank.org/id/ENG00008
# 1     https://data.cooperationdatabank.org/id/ENG00008
# 2     https://data.cooperationdatabank.org/id/ENG00008
# 3     https://data.cooperationdatabank.org/id/ENG00008
# 4     https://data.cooperationdatabank.org/id/ENG00008
# ...                                                ...
# 2486  https://data.cooperationdatabank.org/id/ENG02667
# 2487  https://data.cooperationdatabank.org/id/ENG02668
# 2488  https://data.cooperationdatabank.org/id/ENG02668
# 2489  https://data.cooperationdatabank.org/id/ENG02668
# 2490  https://data.cooperationdatabank.org/id/ENG02672
#
#                                                doi  \
# 0     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 1     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 2     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 3     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 4     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# ...                                            ...
# 2486   http://dx.doi.org/10.2466/pr0.1975.36.2.371
# 2487                          http://dx.doi.org/NA
# 2488                          http://dx.doi.org/NA
# 2489                          http://dx.doi.org/NA
# 2490                          http://dx.doi.org/NA
#
#                                                                        independentProperties  \
# 0                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 1                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 2                           [https://data.cooperationdatabank.org/vocab/prop/positionInGame]
# 3                        [https://data.cooperationdatabank.org/vocab/prop/expectationsLevel]
# 4                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# ...                                                                                      ...
# 2486  [https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate]
# 2487                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 2488                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 2489                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 2490                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
#
#                                                               categoryT1  \
# 0     https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 1     https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 2                                                                      1
# 3          https://data.cooperationdatabank.org/id/expectationslevel/low
# 4     https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# ...                                                                  ...
# 2486                                                                 0.5
# 2487           https://data.cooperationdatabank.org/id/svotype/prosocial
# 2488           https://data.cooperationdatabank.org/id/svotype/prosocial
# 2489       https://data.cooperationdatabank.org/id/svotype/individualist
# 2490       https://data.cooperationdatabank.org/id/svotype/individualist
#
#                                                                         categoryT2
# 0     https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# 1     https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# 2                                                                                2
# 3                   https://data.cooperationdatabank.org/id/expectationslevel/high
# 4     https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# ...                                                                            ...
# 2486                                                                           1.0
# 2487                 https://data.cooperationdatabank.org/id/svotype/individualist
# 2488                    https://data.cooperationdatabank.org/id/svotype/competitor
# 2489                    https://data.cooperationdatabank.org/id/svotype/competitor
# 2490                     https://data.cooperationdatabank.org/id/svotype/prosocial
#
# [2491 rows x 19 columns]

# %%
# obs[["IV_new"]] = obs[["IV_new"]].astype('object')

# %%
#  take out observation that don't have a IV value) 

obs = obs.dropna(subset=['categoryT1', 'categoryT2']).reset_index(drop=True)
obs
# Out:
#                                                               obs  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.3.d
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2.3.d
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1.2.d
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1.2.d
# ...                                                           ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2.3.d
# 2476   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.2.d
# 2477   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.3.d
# 2478   https://data.cooperationdatabank.org/id/ENG02668_1.2.2.3.d
# 2479  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
#
#                                                                     dependent  \
# 0     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 1     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 3     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 4     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                       ...
# 2475    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2476    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2477    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2478    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2479    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
#
#             ES      N  \
# 0     1.243930   57.0
# 1     1.084430   57.0
# 2    -0.087300   58.0
# 3    -0.324082  192.0
# 4     0.315689  144.0
# ...        ...    ...
# 2475  0.100519   48.0
# 2476  0.739089  127.0
# 2477  0.719742  126.0
# 2478 -0.019347  107.0
# 2479 -0.069006   37.0
#
#                                                            t1  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1
# ...                                                       ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2
# 2476   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 2477   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 2478   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 2479  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1
#
#                                                            t2  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.2
# ...                                                       ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667_1b.2.3
# 2476   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 2477   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 2478   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 2479  https://data.cooperationdatabank.org/id/ENG02672_1a.1.2
#
#                                                     study  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1
# 3      https://data.cooperationdatabank.org/id/ENG00008_2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2
# ...                                                   ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667_1b
# 2476   https://data.cooperationdatabank.org/id/ENG02668_1
# 2477   https://data.cooperationdatabank.org/id/ENG02668_1
# 2478   https://data.cooperationdatabank.org/id/ENG02668_1
# 2479  https://data.cooperationdatabank.org/id/ENG02672_1a
#
#                                                                            design  \
# 0     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 1     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# ...                                                                           ...
# 2475  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2476  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2477  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2478  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2479  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
#
#         n1    n2    sd1    sd2   ESLower   ESUpper  \
# 0     28.0  29.0  3.360  3.700  0.676655  1.811200
# 1     28.0  29.0  3.360  4.080  0.528299  1.640570
# 2     29.0  29.0  3.700  4.080 -0.602256  0.427657
# 3     96.0  96.0  3.288  4.281 -0.608830 -0.039335
# 4     96.0  48.0  3.910  3.520 -0.032700  0.664078
# ...    ...   ...    ...    ...       ...       ...
# 2475   NaN   NaN    NaN    NaN -0.552567  0.753605
# 2476   NaN   NaN    NaN    NaN  0.318960  1.159220
# 2477   NaN   NaN    NaN    NaN  0.297905  1.141580
# 2478   NaN   NaN    NaN    NaN -0.438130  0.399437
# 2479   NaN   NaN    NaN    NaN -0.888749  0.750737
#
#                                                  paper  \
# 0     https://data.cooperationdatabank.org/id/ENG00008
# 1     https://data.cooperationdatabank.org/id/ENG00008
# 2     https://data.cooperationdatabank.org/id/ENG00008
# 3     https://data.cooperationdatabank.org/id/ENG00008
# 4     https://data.cooperationdatabank.org/id/ENG00008
# ...                                                ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667
# 2476  https://data.cooperationdatabank.org/id/ENG02668
# 2477  https://data.cooperationdatabank.org/id/ENG02668
# 2478  https://data.cooperationdatabank.org/id/ENG02668
# 2479  https://data.cooperationdatabank.org/id/ENG02672
#
#                                                doi  \
# 0     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 1     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 2     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 3     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 4     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# ...                                            ...
# 2475   http://dx.doi.org/10.2466/pr0.1975.36.2.371
# 2476                          http://dx.doi.org/NA
# 2477                          http://dx.doi.org/NA
# 2478                          http://dx.doi.org/NA
# 2479                          http://dx.doi.org/NA
#
#                                                                        independentProperties  \
# 0                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 1                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# 2                           [https://data.cooperationdatabank.org/vocab/prop/positionInGame]
# 3                        [https://data.cooperationdatabank.org/vocab/prop/expectationsLevel]
# 4                            [https://data.cooperationdatabank.org/vocab/prop/sequentiality]
# ...                                                                                      ...
# 2475  [https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate]
# 2476                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 2477                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 2478                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
# 2479                               [https://data.cooperationdatabank.org/vocab/prop/sVOType]
#
#                                                               categoryT1  \
# 0     https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 1     https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 2                                                                      1
# 3          https://data.cooperationdatabank.org/id/expectationslevel/low
# 4     https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# ...                                                                  ...
# 2475                                                                 0.5
# 2476           https://data.cooperationdatabank.org/id/svotype/prosocial
# 2477           https://data.cooperationdatabank.org/id/svotype/prosocial
# 2478       https://data.cooperationdatabank.org/id/svotype/individualist
# 2479       https://data.cooperationdatabank.org/id/svotype/individualist
#
#                                                                         categoryT2
# 0     https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# 1     https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# 2                                                                                2
# 3                   https://data.cooperationdatabank.org/id/expectationslevel/high
# 4     https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# ...                                                                            ...
# 2475                                                                           1.0
# 2476                 https://data.cooperationdatabank.org/id/svotype/individualist
# 2477                    https://data.cooperationdatabank.org/id/svotype/competitor
# 2478                    https://data.cooperationdatabank.org/id/svotype/competitor
# 2479                     https://data.cooperationdatabank.org/id/svotype/prosocial
#
# [2480 rows x 19 columns]

# %%
type(obs['independentProperties'].unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-2d067295d42c> in <module>
# ----> 1 type(obs['independentProperties'].unique())
#
# c:\users\roos\tf\lib\site-packages\pandas\core\series.py in unique(self)
#    1814         Categories (3, object): [a < b < c]
#    1815         """
# -> 1816         result = super().unique()
#    1817         return result
#    1818
#
# c:\users\roos\tf\lib\site-packages\pandas\core\base.py in unique(self)
#    1244             result = values.unique()
#    1245         else:
# -> 1246             result = unique1d(values)
#    1247
#    1248         return result
#
# c:\users\roos\tf\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     380
#     381     table = htable(len(values))
# --> 382     uniques = table.unique(values)
#     383     uniques = _reconstruct_data(uniques, original.dtype, original)
#     384     return uniques
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
obs.to_csv('data/observations_3.csv')
obs = pd.read_csv('data/observations_3.csv', index_col = 0)

# %%
#  bin continous IV values that create to much hypothesis numbers  

for independent in obs['independentProperties'].unique():
    independent_name = ast.literal_eval(independent)[0]
    catsT1 = obs.loc[obs['independentProperties'] == independent]['categoryT1']
    catsT2 = obs.loc[obs['independentProperties'] == independent]['categoryT2']
    ind_df = obs.loc[obs['independentProperties'] == independent]
                  
    values = np.concatenate((catsT1, catsT2), axis=None)
    cats_unique_len = len(np.unique(values))
    if cats_unique_len > 6:
        try:
            catsT1.astype('float')
            catsfloats = values.astype('float')
        except:
            continue
           
        intervals = pd.qcut(catsfloats, 4, duplicates='drop').categories
        print(intervals)
        for cat in catsT1.unique(): 
            index = np.where(intervals.contains(float(cat)) == True)[0][0]
            obs_indexes = ind_df.loc[ind_df['categoryT1'] == cat].index
            intervals[index]
            obs.at[obs_indexes,'categoryT1'] = intervals[index]
            
        for cat in catsT2.unique(): 
            index = np.where(intervals.contains(float(cat)) == True)[0][0]
            obs_indexes = ind_df.loc[ind_df['categoryT2'] == cat].index
            intervals[index]
            obs.at[obs_indexes,'categoryT2'] = intervals[index]

# %% [markdown]
# ## 2.2 Make IV with Hypothesis Number

# %%
def make_final_IV(obs):    
    lists = []
    sets = []
    loop = tqdm(total = len(obs), position=0, leave=False)
    IVs_and_cats = pd.DataFrame(columns = ['IV', 'catT1', 'catT2', 'number'])
    
    for i, row in obs.iterrows(): 
        IV = ast.literal_eval(row['independentProperties'])[0]
        catT1 = row['categoryT1']
        catT2 = row['categoryT2']
        ES = row['ES']
        ESUp = row['ESUpper']
        ESLo = row['ESLower']
        check_list = [IV, catT1, catT2]
        check_set = set([IV, catT1, catT2])
        
        if check_set not in sets and check_list not in lists:
            lists.append(check_list)
            sets.append(check_set)

            try:
                num = IVs_and_cats['IV'].value_counts()[IV]+1
            except:
                num = 1
            
            df_row = pd.DataFrame([[IV, catT1, catT2, num]], columns = ['IV', 'catT1', 'catT2', 'number'])
            IVs_and_cats = IVs_and_cats.append(df_row, ignore_index=True)
            
            obs.at[i, 'IV_new'] = IV + str('_H') +str(num)  
        
        elif check_set in sets and check_list in lists: 
            
            index = IVs_and_cats.loc[(IVs_and_cats['IV'] == IV) & 
                                     (IVs_and_cats['catT1'] == catT1) &
                                     (IVs_and_cats['catT2'] == catT2)]['number']
            obs.at[i, 'IV_new'] = IV + str('_H') + str(index.values[0])  
            
        elif check_set in sets and check_list not in lists: 
            obs.at[i, 'categoryT1'] = catT2
            obs.at[i, 'categoryT2'] = catT1
            obs.at[i, 'ES'] = (ES * -1)
            obs.at[i, 'ESUpper'] = (ESUp * -1)
            obs.at[i, 'ESLower'] = (ESLo * -1)
            
            index = IVs_and_cats.loc[(IVs_and_cats['IV'] == IV) & 
                                     (IVs_and_cats['catT1'] == catT2) &
                                     (IVs_and_cats['catT2'] == catT1)]['number']
            obs.at[i, 'IV_new'] = IV + str('_H') + str(index.values[0])             
            
        #  Show percentage bar
        loop.set_description("Loading...".format(i))
        loop.update(1)

    loop.close()
    display(IVs_and_cats)
    return obs
obs = make_final_IV(obs)
# Out:
#                                                                      IV  \
# 0         https://data.cooperationdatabank.org/vocab/prop/sequentiality
# 1        https://data.cooperationdatabank.org/vocab/prop/positionInGame
# 2     https://data.cooperationdatabank.org/vocab/prop/expectationsLevel
# 3        https://data.cooperationdatabank.org/vocab/prop/religiousLevel
# 4    https://data.cooperationdatabank.org/vocab/prop/blockOfCooperation
# ..                                                                  ...
# 377      https://data.cooperationdatabank.org/vocab/prop/emotionValence
# 378      https://data.cooperationdatabank.org/vocab/prop/emotionValence
# 379         https://data.cooperationdatabank.org/vocab/prop/nationality
# 380  https://data.cooperationdatabank.org/vocab/prop/conflictIndexLevel
# 381  https://data.cooperationdatabank.org/vocab/prop/conflictIndexLevel
#
#                                                                   catT1  \
# 0    https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 1                                                                     1
# 2         https://data.cooperationdatabank.org/id/expectationslevel/low
# 3           https://data.cooperationdatabank.org/id/religiouslevel/high
# 4                                                                     1
# ..                                                                  ...
# 377     https://data.cooperationdatabank.org/id/emotionvalence/positive
# 378      https://data.cooperationdatabank.org/id/emotionvalence/neutral
# 379                                                                 GBR
# 380      https://data.cooperationdatabank.org/id/conflictindexlevel/low
# 381   https://data.cooperationdatabank.org/id/conflictindexlevel/medium
#
#                                                                             catT2  \
# 0    https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# 1                                                                               2
# 2                  https://data.cooperationdatabank.org/id/expectationslevel/high
# 3                      https://data.cooperationdatabank.org/id/religiouslevel/low
# 4                                                                               2
# ..                                                                            ...
# 377               https://data.cooperationdatabank.org/id/emotionvalence/negative
# 378               https://data.cooperationdatabank.org/id/emotionvalence/negative
# 379                                                                           DEU
# 380             https://data.cooperationdatabank.org/id/conflictindexlevel/medium
# 381               https://data.cooperationdatabank.org/id/conflictindexlevel/high
#
#     number
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 377      2
# 378      3
# 379     24
# 380      2
# 381      3
#
# [382 rows x 4 columns]

# %%
obs
# Out:
#                                                               obs  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1.3.d
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2.3.d
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1.2.d
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1.2.d
# ...                                                           ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2.3.d
# 2476   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.2.d
# 2477   https://data.cooperationdatabank.org/id/ENG02668_1.2.1.3.d
# 2478   https://data.cooperationdatabank.org/id/ENG02668_1.2.2.3.d
# 2479  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
#
#                                                                     dependent  \
# 0     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 1     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 3     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 4     https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                       ...
# 2475    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2476    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2477    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2478    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
# 2479    https://data.cooperationdatabank.org/id/dependentvariable/cooperation
#
#             ES      N  \
# 0     1.243930   57.0
# 1     1.084430   57.0
# 2    -0.087300   58.0
# 3    -0.324082  192.0
# 4     0.315689  144.0
# ...        ...    ...
# 2475 -0.100519   48.0
# 2476 -0.739089  127.0
# 2477  0.719742  126.0
# 2478 -0.019347  107.0
# 2479 -0.069006   37.0
#
#                                                            t1  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.1
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.1
# ...                                                       ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667_1b.2.2
# 2476   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 2477   https://data.cooperationdatabank.org/id/ENG02668_1.2.1
# 2478   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 2479  https://data.cooperationdatabank.org/id/ENG02672_1a.1.1
#
#                                                            t2  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1.4.2
# 1      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 2      https://data.cooperationdatabank.org/id/ENG00008_1.4.3
# 3      https://data.cooperationdatabank.org/id/ENG00008_2.1.2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2.2.2
# ...                                                       ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667_1b.2.3
# 2476   https://data.cooperationdatabank.org/id/ENG02668_1.2.2
# 2477   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 2478   https://data.cooperationdatabank.org/id/ENG02668_1.2.3
# 2479  https://data.cooperationdatabank.org/id/ENG02672_1a.1.2
#
#                                                     study  \
# 0      https://data.cooperationdatabank.org/id/ENG00008_1
# 1      https://data.cooperationdatabank.org/id/ENG00008_1
# 2      https://data.cooperationdatabank.org/id/ENG00008_1
# 3      https://data.cooperationdatabank.org/id/ENG00008_2
# 4      https://data.cooperationdatabank.org/id/ENG00008_2
# ...                                                   ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667_1b
# 2476   https://data.cooperationdatabank.org/id/ENG02668_1
# 2477   https://data.cooperationdatabank.org/id/ENG02668_1
# 2478   https://data.cooperationdatabank.org/id/ENG02668_1
# 2479  https://data.cooperationdatabank.org/id/ENG02672_1a
#
#                                                                            design  \
# 0     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 1     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 3     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 4     https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# ...                                                                           ...
# 2475  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2476  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2477  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2478  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
# 2479  https://data.cooperationdatabank.org/id/betweenorwithinparticipantsdesign/1
#
#         n1    n2    sd1    sd2   ESLower   ESUpper  \
# 0     28.0  29.0  3.360  3.700  0.676655  1.811200
# 1     28.0  29.0  3.360  4.080  0.528299  1.640570
# 2     29.0  29.0  3.700  4.080 -0.602256  0.427657
# 3     96.0  96.0  3.288  4.281 -0.608830 -0.039335
# 4     96.0  48.0  3.910  3.520 -0.032700  0.664078
# ...    ...   ...    ...    ...       ...       ...
# 2475   NaN   NaN    NaN    NaN  0.552567 -0.753605
# 2476   NaN   NaN    NaN    NaN -0.318960 -1.159220
# 2477   NaN   NaN    NaN    NaN  0.297905  1.141580
# 2478   NaN   NaN    NaN    NaN -0.438130  0.399437
# 2479   NaN   NaN    NaN    NaN -0.888749  0.750737
#
#                                                  paper  \
# 0     https://data.cooperationdatabank.org/id/ENG00008
# 1     https://data.cooperationdatabank.org/id/ENG00008
# 2     https://data.cooperationdatabank.org/id/ENG00008
# 3     https://data.cooperationdatabank.org/id/ENG00008
# 4     https://data.cooperationdatabank.org/id/ENG00008
# ...                                                ...
# 2475  https://data.cooperationdatabank.org/id/ENG02667
# 2476  https://data.cooperationdatabank.org/id/ENG02668
# 2477  https://data.cooperationdatabank.org/id/ENG02668
# 2478  https://data.cooperationdatabank.org/id/ENG02668
# 2479  https://data.cooperationdatabank.org/id/ENG02672
#
#                                                doi  \
# 0     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 1     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 2     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 3     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# 4     http://dx.doi.org/10.1016/j.jesp.2004.09.004
# ...                                            ...
# 2475   http://dx.doi.org/10.2466/pr0.1975.36.2.371
# 2476                          http://dx.doi.org/NA
# 2477                          http://dx.doi.org/NA
# 2478                          http://dx.doi.org/NA
# 2479                          http://dx.doi.org/NA
#
#                                                                          independentProperties  \
# 0                            ['https://data.cooperationdatabank.org/vocab/prop/sequentiality']
# 1                            ['https://data.cooperationdatabank.org/vocab/prop/sequentiality']
# 2                           ['https://data.cooperationdatabank.org/vocab/prop/positionInGame']
# 3                        ['https://data.cooperationdatabank.org/vocab/prop/expectationsLevel']
# 4                            ['https://data.cooperationdatabank.org/vocab/prop/sequentiality']
# ...                                                                                        ...
# 2475  ['https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate']
# 2476                               ['https://data.cooperationdatabank.org/vocab/prop/sVOType']
# 2477                               ['https://data.cooperationdatabank.org/vocab/prop/sVOType']
# 2478                               ['https://data.cooperationdatabank.org/vocab/prop/sVOType']
# 2479                               ['https://data.cooperationdatabank.org/vocab/prop/sVOType']
#
#                                                               categoryT1  \
# 0     https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 1     https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 2                                                                      1
# 3          https://data.cooperationdatabank.org/id/expectationslevel/low
# 4     https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# ...                                                                  ...
# 2475                                                       (0.962, 2.46]
# 2476       https://data.cooperationdatabank.org/id/svotype/individualist
# 2477           https://data.cooperationdatabank.org/id/svotype/prosocial
# 2478       https://data.cooperationdatabank.org/id/svotype/individualist
# 2479       https://data.cooperationdatabank.org/id/svotype/individualist
#
#                                                                         categoryT2  \
# 0     https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# 1     https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# 2                                                                                2
# 3                   https://data.cooperationdatabank.org/id/expectationslevel/high
# 4     https://data.cooperationdatabank.org/id/sequentiality/sequential_turn-taking
# ...                                                                            ...
# 2475                                                                    (0.1, 0.5]
# 2476                     https://data.cooperationdatabank.org/id/svotype/prosocial
# 2477                    https://data.cooperationdatabank.org/id/svotype/competitor
# 2478                    https://data.cooperationdatabank.org/id/svotype/competitor
# 2479                     https://data.cooperationdatabank.org/id/svotype/prosocial
#
#                                                                                        IV_new
# 0                            https://data.cooperationdatabank.org/vocab/prop/sequentiality_H1
# 1                            https://data.cooperationdatabank.org/vocab/prop/sequentiality_H1
# 2                           https://data.cooperationdatabank.org/vocab/prop/positionInGame_H1
# 3                        https://data.cooperationdatabank.org/vocab/prop/expectationsLevel_H1
# 4                            https://data.cooperationdatabank.org/vocab/prop/sequentiality_H1
# ...                                                                                       ...
# 2475  https://data.cooperationdatabank.org/vocab/prop/iteratedPreprogrammedCooperationRate_H3
# 2476                               https://data.cooperationdatabank.org/vocab/prop/sVOType_H1
# 2477                              https://data.cooperationdatabank.org/vocab/prop/sVOType_H10
# 2478                               https://data.cooperationdatabank.org/vocab/prop/sVOType_H4
# 2479                               https://data.cooperationdatabank.org/vocab/prop/sVOType_H1
#
# [2480 rows x 20 columns]

# %% [markdown]
# ## 2.3 Binning Effect Sizes

# %%
#  Binning effect sizes 

bins = [-np.inf, -0.5, -0.2, 0.2, 0.5, np.inf]
labels = ['LargeMediumNegativeES',
'SmallNegativeES',
'NullFinding',  
'SmallPositiveES',
'LargeMediumPositiveES'] 
categories = pd.cut(obs['ES'], bins, labels = labels)
obs['ESType'] = categories

# %%
# retrieval = pd.read_csv('data/observations_with_intervals_final.csv', index_col=0)
# retrieval

# %%
# indexes = retrieval['ESLower'].index[retrieval['ESLower'].isnull()]
# for index in indexes: 
#     print(retrieval.at[index, 'SE'])

# %% [markdown]
# # 3. From data table to triple

# %%
from validator_collection import validators, checkers

def make_effect_query(obs, IV, IV_H, catT1, catT2, es_type, effect = 'noEffect'): 
    if checkers.is_url(catT1) and checkers.is_url(catT2) == True: 
        value_lineT1 = '?t1 <' + IV + '> <' + catT1 + '> . '
        value_lineT2 = '?t2 <' + IV + '> <' + catT2 + '> . '
    else:         
        value_lineT1 = '?t1 <' + IV + '> "' + str(catT1) + '" .'
        value_lineT2 = '?t2 <' + IV + '> "' + str(catT2) + '" .'

    cp_effect = '<' + IV_H + '>' + ' cp:hasNoEffectOn ?dependentVariable .'
    
    if effect == 'positive': 
        cp_effect = '<' + IV_H + '>' + ' cp:hasPositiveEffectOn ?dependentVariable .'

    elif effect == 'negative': 
        cp_effect = '<' + IV_H + '>' + ' cp:hasNegativeEffectOn ?dependentVariable .'
        
        
    query = """ 
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX cp: <https://data.cooperationdatabank.org/vocab/prop/>
PREFIX class: <https://data.cooperationdatabank.org/vocab/class/>

CONSTRUCT {
  # ?study cp:reportsEffect """ + '<' + obs + '>' + """ . 
  """ + '<' + obs + '>' + """ cp:dependentVariable ?dependentVariable .
  """ + '<' + obs + '>' + """ cp:ESType  class:""" + es_type + """ . 
  """ + '<' + obs + '>' + """ cp:treatment ?t1, ?t2 .
  """ + '<' + IV + '>' + """ rdfs:subPropertyOf ?superProperty . 
  
  """ + value_lineT1 + value_lineT2 + cp_effect + '<' + IV + '>' + """ rdfs:range ?class . 
  # ?class rdfs:subClassOf ?superClass . 
  # ?superClass rdfs:subClassOf class:IndependentVariable . 
   """ + '<' + IV_H + '>' + """ rdfs:subPropertyOf  """ + '<' + IV + '>' + """ . 
} 

WHERE {
  # ?study cp:reportsEffect """ + '<' + obs + '>' + """ . 
  """ + '<' + obs + '>' + """ rdf:type class:Observation .
  """ + '<' + obs + '>' + """ cp:eSmeasure <https://data.cooperationdatabank.org/id/esmeasure/d> . 
  """ + '<' + obs + '>' + """ cp:dependentVariable ?dependentVariable .
  """ + '<' + obs + '>' + """ cp:treatment ?t1, ?t2 . 
""" + '<' + IV + '>' + """ rdfs:subPropertyOf ?superProperty . 
  
  OPTIONAL { 
  """ + value_lineT1 + value_lineT2 + """
  }
  OPTIONAL {
    """ + '<' + IV + '>' + """ rdfs:range ?class . 
    # ?class rdfs:subClassOf ?superClass . 
    # ?superClass rdfs:subClassOf class:IndependentVariable . 
  }
FILTER (?t1 < ?t2)
} """
    return query

# %%
def zero_is_between(start, stop): 
    if start <= 0 <= stop: 
        return True
    else: 
        return False 
    
    
#  if 0 is between lower and upper bounds then the effect is not significant 
def type_of_effect(effect_size, lower, upper):
    effect = ''
    if math.isnan(lower) or math.isnan(upper):
        if effect_size > -0.2 and effect_size < 0.2:
            effect = 'noEffect'
            
        elif effect_size > 0.2: 
            effect = 'positive'
            
        elif effect_size < -0.2: 
            effect = 'negative'
    else: 
        # not significant effect sizes 
        if zero_is_between(lower, upper): 
            effect = 'noEffect'

        # significant effect sizes 
        elif not zero_is_between(lower, upper):
            
            #  positive effect sizes 
            if float(effect_size) > 0:
                effect = 'positive'

            #  negative effect sizes 
            elif float(effect_size) < 0: 
                effect = 'negative'
    
    return effect

# %%
def table_to_triples(table):
    #  Initiate empty triples_df 
    tripels_df = pd.DataFrame(columns=['s', 'p', 'o'])
    
    loop = tqdm(total = len(table), position=0, leave=False)

    for index, row in table.iterrows():        
        # Get stuff from df row
        observation = row['obs']
        lower = float(row['ESLower'])
        upper = float(row['ESUpper'])
        es_type = row['ESType']
        IV = ast.literal_eval(row['independentProperties'])[0]
        IV_H = row['IV_new']
        cat1 = row['categoryT1']
        cat2 = row['categoryT2']
        effect_size = row['ES']
#         standard_error = row['SE']
        
        #  if lower or upper are not in the data, calculate them 
        if math.isnan(lower) or math.isnan(upper): 
            try: 
                lower = effect_size - (1.96 * standard_error)
                upper = effect_size + (1.96 * standard_error)
    
                #  Retrieve type of effect (negative, noEffect, positive)
                effect = type_of_effect(effect_size, lower, upper)
            except: 
                effect = type_of_effect(effect_size, lower, upper)
        else: 
            effect = type_of_effect(effect_size, lower, upper)
        
        
        #  make query 
        query = make_effect_query(observation, IV, IV_H, cat1, cat2, es_type, effect = effect) 
        
        #  get df with tripels 
        new_triples = get_sparql_dataframe_construct(url, query)

        #  append triples to the full df
        tripels_df = tripels_df.append(new_triples)
                
        #  Show percentage bar to see how far allong we are 
        loop.set_description("Loading...".format(index))
        loop.update(1)
    
    loop.close()
    return tripels_df.reset_index(drop=True)

triples = table_to_triples(obs)

# %%
triples
# Out:
#                                                                             s  \
# 0      https://data.cooperationdatabank.org/vocab/class/SequentialityVariable
# 1            https://data.cooperationdatabank.org/vocab/prop/sequentiality_H1
# 2                      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 3                  https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 4                  https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# ...                                                                       ...
# 29754             https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
# 29755    https://data.cooperationdatabank.org/vocab/class/PersonalityVariable
# 29756                 https://data.cooperationdatabank.org/id/ENG02672_1a.1.1
# 29757                     https://data.cooperationdatabank.org/id/ENG02672_1a
# 29758                https://data.cooperationdatabank.org/vocab/class/SVOType
#
#                                                                          p  \
# 0                          http://www.w3.org/2000/01/rdf-schema#subClassOf
# 1      https://data.cooperationdatabank.org/vocab/prop/hasPositiveEffectOn
# 2            https://data.cooperationdatabank.org/vocab/prop/sequentiality
# 3                   https://data.cooperationdatabank.org/vocab/prop/ESType
# 4        https://data.cooperationdatabank.org/vocab/prop/dependentVariable
# ...                                                                    ...
# 29754               https://data.cooperationdatabank.org/vocab/prop/ESType
# 29755                      http://www.w3.org/2000/01/rdf-schema#subClassOf
# 29756              https://data.cooperationdatabank.org/vocab/prop/sVOType
# 29757        https://data.cooperationdatabank.org/vocab/prop/reportsEffect
# 29758                      http://www.w3.org/2000/01/rdf-schema#subClassOf
#
#                                                                              o
# 0         https://data.cooperationdatabank.org/vocab/class/IndependentVariable
# 1      https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2           https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 3       https://data.cooperationdatabank.org/vocab/class/LargeMediumPositiveES
# 4      https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                        ...
# 29754             https://data.cooperationdatabank.org/vocab/class/NullFinding
# 29755     https://data.cooperationdatabank.org/vocab/class/IndependentVariable
# 29756            https://data.cooperationdatabank.org/id/svotype/individualist
# 29757              https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
# 29758     https://data.cooperationdatabank.org/vocab/class/PersonalityVariable
#
# [29759 rows x 3 columns]

# %%
triples.to_csv('data/triples.csv')
triples = pd.read_csv('data/triples.csv', index_col=0)

# %%
triples
# Out:
#                                                                             s  \
# 0      https://data.cooperationdatabank.org/vocab/class/SequentialityVariable
# 1            https://data.cooperationdatabank.org/vocab/prop/sequentiality_H1
# 2                      https://data.cooperationdatabank.org/id/ENG00008_1.4.1
# 3                  https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# 4                  https://data.cooperationdatabank.org/id/ENG00008_1.4.1.2.d
# ...                                                                       ...
# 29754             https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
# 29755    https://data.cooperationdatabank.org/vocab/class/PersonalityVariable
# 29756                 https://data.cooperationdatabank.org/id/ENG02672_1a.1.1
# 29757                     https://data.cooperationdatabank.org/id/ENG02672_1a
# 29758                https://data.cooperationdatabank.org/vocab/class/SVOType
#
#                                                                          p  \
# 0                          http://www.w3.org/2000/01/rdf-schema#subClassOf
# 1      https://data.cooperationdatabank.org/vocab/prop/hasPositiveEffectOn
# 2            https://data.cooperationdatabank.org/vocab/prop/sequentiality
# 3                   https://data.cooperationdatabank.org/vocab/prop/ESType
# 4        https://data.cooperationdatabank.org/vocab/prop/dependentVariable
# ...                                                                    ...
# 29754               https://data.cooperationdatabank.org/vocab/prop/ESType
# 29755                      http://www.w3.org/2000/01/rdf-schema#subClassOf
# 29756              https://data.cooperationdatabank.org/vocab/prop/sVOType
# 29757        https://data.cooperationdatabank.org/vocab/prop/reportsEffect
# 29758                      http://www.w3.org/2000/01/rdf-schema#subClassOf
#
#                                                                              o
# 0         https://data.cooperationdatabank.org/vocab/class/IndependentVariable
# 1      https://data.cooperationdatabank.org/id/dependentvariable/contributions
# 2           https://data.cooperationdatabank.org/id/sequentiality/simultaneous
# 3       https://data.cooperationdatabank.org/vocab/class/LargeMediumPositiveES
# 4      https://data.cooperationdatabank.org/id/dependentvariable/contributions
# ...                                                                        ...
# 29754             https://data.cooperationdatabank.org/vocab/class/NullFinding
# 29755     https://data.cooperationdatabank.org/vocab/class/IndependentVariable
# 29756            https://data.cooperationdatabank.org/id/svotype/individualist
# 29757              https://data.cooperationdatabank.org/id/ENG02672_1a.1.1.2.d
# 29758     https://data.cooperationdatabank.org/vocab/class/PersonalityVariable
#
# [29759 rows x 3 columns]

# %%
def convert_to_array(df):
    listje = []
    loop = tqdm(total = len(df), position=0, leave=False)
    for index, row in df.iterrows():
        listje.append([row['s'], row['p'], row['o']])  
            
        #  Show percentage bar to see how far allong we are 
        loop.set_description("Loading...".format(index))
        loop.update(1)

    array = np.asarray(listje)
    return array

# %%
triples_arr = convert_to_array(triples)
# Out:
# Loading...:  23%|██████████████▋                                                 | 6826/29759 [00:07<00:24, 942.26it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-c831777d7fa2> in <module>
# ----> 1 triples_arr = convert_to_array(triples)
#
# <ipython-input-73-f0ac1b7a89df> in convert_to_array(df)
#       6
#       7         #  Show percentage bar to see how far allong we are
# ----> 8         loop.set_description("Loading...".format(index))
#       9         loop.update(1)
#      10
#
# c:\users\roos\tf\lib\site-packages\tqdm\std.py in set_description(self, desc, refresh)
#    1373         self.desc = desc + ': ' if desc else ''
#    1374         if refresh:
# -> 1375             self.refresh()
#    1376
#    1377     def set_description_str(self, desc=None, refresh=True):
#
# c:\users\roos\tf\lib\site-packages\tqdm\std.py in refresh(self, nolock, lock_args)
#    1334             else:
#    1335                 self._lock.acquire()
# -> 1336         self.display()
#    1337         if not nolock:
#    1338             self._lock.release()
#
# c:\users\roos\tf\lib\site-packages\tqdm\std.py in display(self, msg, pos)
#    1467         if pos:
#    1468             self.moveto(pos)
# -> 1469         self.sp(self.__repr__() if msg is None else msg)
#    1470         if pos:
#    1471             self.moveto(-pos)
#
# c:\users\roos\tf\lib\site-packages\tqdm\std.py in print_status(s)
#     303         def print_status(s):
#     304             len_s = len(s)
# --> 305             fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     306             last_len[0] = len_s
#     307
#
# c:\users\roos\tf\lib\site-packages\tqdm\std.py in fp_write(s)
#     297         def fp_write(s):
#     298             fp.write(_unicode(s))
# --> 299             fp_flush()
#     300
#     301         last_len = [0]
#
# c:\users\roos\tf\lib\site-packages\ipykernel\iostream.py in flush(self)
#     341         if self.pub_thread and self.pub_thread.thread is not None and self.pub_thread.thread.is_alive():
#     342             # request flush on the background thread
# --> 343             self.pub_thread.schedule(self._flush)
#     344             # wait for flush to actually get through, if we can.
#     345             # waiting across threads during import can cause deadlocks
#
# c:\users\roos\tf\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# c:\users\roos\tf\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\users\roos\tf\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
triples_arr1 = triples.to_numpy()

# %%
print(len(triples_arr))
triples_arr

# %%
full_CoDa_data_df = triples

# %% [markdown]
# # Create seen, unseen triples

# %%
#  Filter out out the effect triples 

df_hasPositiveEffectOn_only = full_CoDa_data_df[(full_CoDa_data_df.p == 'https://data.cooperationdatabank.org/vocab/prop/hasPositiveEffectOn')]
df_hasNoEffectOn_only = full_CoDa_data_df[(full_CoDa_data_df.p == 'https://data.cooperationdatabank.org/vocab/prop/hasNoEffectOn')]
df_hasNegativeEffectOn_only = full_CoDa_data_df[(full_CoDa_data_df.p == 'https://data.cooperationdatabank.org/vocab/prop/hasNegativeEffectOn')]

# %%
print(len(df_hasPositiveEffectOn_only))
print(len(df_hasNoEffectOn_only))
print(len(df_hasNegativeEffectOn_only))

# %%
#  Put all effect triples together 

effect_triples_df = pd.concat([df_hasPositiveEffectOn_only, df_hasNegativeEffectOn_only])
print(len(effect_triples_df))
effect_triples_df

# %%
#  Count and check unique entities and relationships 

s_unique = list(effect_triples_df["s"].unique())
p_unique = list(effect_triples_df["p"].unique())
o_unique = list(effect_triples_df["o"].unique())

print(len(s_unique), s_unique)
print(len(p_unique), p_unique)
print(len(o_unique), o_unique)

# %%
#  Create all possible effect triples using the seen effect triples 

df_unseen = []

def make_doubles(s_all,p_all,o_all):  
    doubles = []
    for s in s_all: 
        triple = []
        iterations_p = len(p_all)   
   
        while iterations_p: 
            triple = []
            iterations_p-=1
            triple.append(s)
            triple.append(p_all[iterations_p])
            doubles.append(triple)
    return doubles 


def make_triples(s_p, o_all): 
    list_with_triples = []
    iterations_o = len(o_all)
    for double in s_p: 
        triple = [double]
        iterations_o = len(o_all)
        while iterations_o:
            iterations_o-=1
            triple_finish = double + [o_all[iterations_o]]
            list_with_triples.append(triple_finish)
    return list_with_triples


doubles = make_doubles(s_unique, p_unique, o_unique)

yay_triples = make_triples(doubles, o_unique)
print(len(yay_triples))

# %%
#  See all the possible triples in a df for inspection  

all_triples = pd.DataFrame(yay_triples, columns=list('spo'))
all_triples

# %%
#  drop duplicates and turn into array for seen triples input in ComplEx

seen_triples = effect_triples_df.drop_duplicates()
len(seen_triples)

# %%
def triple_filter(df1, df2): 
    unseen_triples = df1
    for index, row in df2.iterrows():
        match = df1[(df1==row).all(axis=1)]
        index = match.index.astype(int)
        unseen_triples = unseen_triples.drop(match.index, axis=0)

    return unseen_triples  

#  Filter out all unseen triples using the triple filter 
unseen_triples = triple_filter(all_triples, seen_triples)
len(unseen_triples)

# %%
unseen_triples_arr = unseen_triples

# %%
# %store triples_arr
# %store unseen_triples_arr

# %%
np.save('triples2244.npy', triples_arr)
